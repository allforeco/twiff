# %% [markdown]
# # Searching

# %%
# %run search.py
# Out:
# [ 2022-01-11 21:40:17,269 ] __main__ (INFO): Namespace(key_path='keys.json', cursor_path='cursor.json', export_dir='exports', log_dir='logs', query='(#twiff OR #Twiff) -is:retweet', max_results=100, max_tweets=1000)
# [ 2022-01-11 21:40:17,269 ] utils (INFO): Loading... 'Cursor (None): oldest_id=None, newest_id=None'
# [ 2022-01-11 21:40:17,270 ] utils (INFO): Loading... 'Cursor (cursor.json): oldest_id=1478692134974902273, newest_id=1479474025596260355'
# [ 2022-01-11 21:40:17,271 ] utils (INFO): Keys loaded...
# [ 2022-01-11 21:40:17,272 ] __main__ (INFO): ----- [ Request 1 ] -----
# [ 2022-01-11 21:40:17,272 ] __main__ (INFO): Searching for relevant tweets between 1479474025596260355 and None...
# [ 2022-01-11 21:40:17,527 ] utils (WARNING): No tweets were retrieved.
# [ 2022-01-11 21:40:17,528 ] __main__ (INFO): Search complete, found 0 tweets. Exiting...

# %%
from utils import *
import tweepy

# API keys
keys = Keys('keys.json')

# Initialise tweepy client
client = tweepy.Client(keys.bearer_token, 
                       keys.api_key, keys.api_key_secret, 
                       keys.access_token, keys.access_token_secret,
                       return_type=dict, wait_on_rate_limit=True
                      )
# Out:
# [ 2022-01-11 21:40:21,891 ] utils (INFO): Keys loaded...

# %%
from utils import *

results = Results()
results._load('exports')

for tweet in results.tweets.values():
    print('{} @ {} by {}' .format(tweet.id, tweet.created_at, results.users[tweet.author_id].name))
# Out:
# [ 2022-01-11 16:14:24,952 ] utils (INFO): Loading 82 tweets...
# [ 2022-01-11 16:14:25,238 ] utils (INFO): Loading 242 users...
# 1466075160843276298 @ 2021-12-01T16:02:11.000Z by 💧 Janine Climate #UprootTheSystem
# 1466117777136050177 @ 2021-12-01T18:51:31.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1466118638562426881 @ 2021-12-01T18:54:57.000Z by 💧 Janine Climate #UprootTheSystem
# 1466437155765563412 @ 2021-12-02T16:00:37.000Z by 💧 Janine Climate #UprootTheSystem
# 1466885984994349057 @ 2021-12-03T21:44:06.000Z by 💧 Janine Climate #UprootTheSystem
# 1466887738452496384 @ 2021-12-03T21:51:04.000Z by 💧 Janine Climate #UprootTheSystem
# 1466888367480651788 @ 2021-12-03T21:53:34.000Z by 💧 Janine Climate #UprootTheSystem
# 1466894039224045578 @ 2021-12-03T22:16:07.000Z by @FFF_SAJ ._. Sweden Årsta Janine #UprootTheSystem
# 1467446392125861890 @ 2021-12-05T10:50:58.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1467448015384371200 @ 2021-12-05T10:57:25.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1467450340341653508 @ 2021-12-05T11:06:39.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1467578842399313926 @ 2021-12-05T19:37:16.000Z by 11thHFC
# 1467806531311788040 @ 2021-12-06T10:42:02.000Z by 💧 Janine Climate #UprootTheSystem
# 1467807940262477825 @ 2021-12-06T10:47:38.000Z by 💧 Janine Climate #UprootTheSystem
# 1467809152600789028 @ 2021-12-06T10:52:27.000Z by 💧 Janine Climate #UprootTheSystem
# 1467810539652980741 @ 2021-12-06T10:57:57.000Z by 💧 Janine Climate #UprootTheSystem
# 1467811401586642946 @ 2021-12-06T11:01:23.000Z by 💧 Janine Climate #UprootTheSystem
# 1467813536349003776 @ 2021-12-06T11:09:52.000Z by 💧 Janine Climate #UprootTheSystem
# 1467814415185727493 @ 2021-12-06T11:13:21.000Z by 💧 Janine Climate #UprootTheSystem
# 1467818568754634758 @ 2021-12-06T11:29:52.000Z by 💧 Janine Climate #UprootTheSystem
# 1467825346791759872 @ 2021-12-06T11:56:48.000Z by 💧 Janine Climate #UprootTheSystem
# 1467827378642694147 @ 2021-12-06T12:04:52.000Z by 💧 Janine Climate #UprootTheSystem
# 1467878798150488066 @ 2021-12-06T15:29:12.000Z by 💧 Janine Climate #UprootTheSystem
# 1468572384340983813 @ 2021-12-08T13:25:15.000Z by @Twiff_bot 🌏 #Twiff
# 1469956781208223746 @ 2021-12-12T09:06:21.000Z by 💧 Janine Climate #UprootTheSystem
# 1470200239760068613 @ 2021-12-13T01:13:46.000Z by Mario Lanza
# 1470362662198554626 @ 2021-12-13T11:59:11.000Z by 💧 Janine Climate #UprootTheSystem
# 1470370904148488196 @ 2021-12-13T12:31:56.000Z by 💧 Janine Climate #UprootTheSystem
# 1470821530414243840 @ 2021-12-14T18:22:34.000Z by 💧 Janine Climate #UprootTheSystem
# 1471921382233714697 @ 2021-12-17T19:12:59.000Z by 💧 Janine Climate #UprootTheSystem
# 1471922072213499917 @ 2021-12-17T19:15:43.000Z by 💧 Janine Climate #UprootTheSystem
# 1471923428072509450 @ 2021-12-17T19:21:06.000Z by 💧 Janine Climate #UprootTheSystem
# 1471924280044703757 @ 2021-12-17T19:24:30.000Z by 💧 Janine Climate #UprootTheSystem
# 1471925765642063881 @ 2021-12-17T19:30:24.000Z by 💧 Janine Climate #UprootTheSystem
# 1471939938757353481 @ 2021-12-17T20:26:43.000Z by 💧 Janine Climate #UprootTheSystem
# 1471948902865772559 @ 2021-12-17T21:02:20.000Z by 💧 Janine Climate #UprootTheSystem
# 1471949423521714176 @ 2021-12-17T21:04:24.000Z by 💧 Janine Climate #UprootTheSystem
# 1471950074053906439 @ 2021-12-17T21:06:59.000Z by 💧 Janine Climate #UprootTheSystem
# 1471950743167021066 @ 2021-12-17T21:09:39.000Z by 💧 Janine Climate #UprootTheSystem
# 1471968708285415428 @ 2021-12-17T22:21:02.000Z by 💧 Janine Climate #UprootTheSystem
# 1471971031560691727 @ 2021-12-17T22:30:16.000Z by 💧 Janine Climate #UprootTheSystem
# 1471971600027336708 @ 2021-12-17T22:32:32.000Z by 💧 Janine Climate #UprootTheSystem
# 1472143800512438282 @ 2021-12-18T09:56:47.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1472144257419030530 @ 2021-12-18T09:58:36.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1472144756063064066 @ 2021-12-18T10:00:35.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1472145220997373952 @ 2021-12-18T10:02:26.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1472148726798077952 @ 2021-12-18T10:16:22.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1472315758680100864 @ 2021-12-18T21:20:05.000Z by 💧 Janine Climate #UprootTheSystem
# 1472883409978593280 @ 2021-12-20T10:55:44.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# 1472884160268283907 @ 2021-12-20T10:58:43.000Z by Fridays For Future AO #UprootTheSystem
# 1473006074148147202 @ 2021-12-20T19:03:09.000Z by 💧 Janine Climate #UprootTheSystem
# 1473576069512921093 @ 2021-12-22T08:48:07.000Z by @Twiff_bot 🌏 #Twiff
# 1473576395166998532 @ 2021-12-22T08:49:24.000Z by @Twiff_bot 🌏 #Twiff
# 1474313058134761475 @ 2021-12-24T09:36:39.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# 1474351677675348000 @ 2021-12-24T12:10:06.000Z by Barbara Fischer
# 1474351793379454979 @ 2021-12-24T12:10:34.000Z by Barbara Fischer
# 1474351985981804549 @ 2021-12-24T12:11:20.000Z by Barbara Fischer
# 1475789543785877508 @ 2021-12-28T11:23:40.000Z by 💧 Janine Climate #UprootTheSystem
# 1475936120265445377 @ 2021-12-28T21:06:07.000Z by 💧 Janine Climate #UprootTheSystem
# 1476294800123076609 @ 2021-12-29T20:51:23.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# 1476702297862377476 @ 2021-12-30T23:50:38.000Z by Barbara Fischer
# 1476830531660754944 @ 2021-12-31T08:20:11.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# 1476833103880597504 @ 2021-12-31T08:30:24.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# 1476851470318379026 @ 2021-12-31T09:43:23.000Z by Barbara Fischer
# 1476864235862958111 @ 2021-12-31T10:34:07.000Z by Barbara Fischer
# 1476868574216011776 @ 2021-12-31T10:51:21.000Z by Nasadox
# 1476872063654768641 @ 2021-12-31T11:05:13.000Z by Tom #FFFMapCount💚🌍🌎🌏💚
# 1476943674068111399 @ 2021-12-31T15:49:46.000Z by 💧 Janine Climate #UprootTheSystem
# 1476945512809050114 @ 2021-12-31T15:57:05.000Z by 💧 Janine Climate #UprootTheSystem
# 1476948328139169808 @ 2021-12-31T16:08:16.000Z by 💧 Janine Climate #UprootTheSystem
# 1476967914930679809 @ 2021-12-31T17:26:06.000Z by 💧 Janine Climate #UprootTheSystem
# 1477214484754276353 @ 2022-01-01T09:45:53.000Z by 💧 Janine Climate #UprootTheSystem
# 1478692134974902273 @ 2022-01-05T11:37:32.000Z by 💧 Janine Climate #UprootTheSystem
# 1479358880165552128 @ 2022-01-07T07:46:56.000Z by 💧 Janine Climate #UprootTheSystem
# 1479367839203139587 @ 2022-01-07T08:22:32.000Z by 💧 Janine Climate #UprootTheSystem
# 1479368870511136772 @ 2022-01-07T08:26:38.000Z by 💧 Janine Climate #UprootTheSystem
# 1479370161606078466 @ 2022-01-07T08:31:46.000Z by 💧 Janine Climate #UprootTheSystem
# 1479370775543091201 @ 2022-01-07T08:34:12.000Z by 💧 Janine Climate #UprootTheSystem
# 1479373300019208196 @ 2022-01-07T08:44:14.000Z by 💧 Janine Climate #UprootTheSystem
# 1479383912484900866 @ 2022-01-07T09:26:25.000Z by Barbara Fischer
# 1479422653572255745 @ 2022-01-07T12:00:21.000Z by 💧 Janine Climate #UprootTheSystem
# 1479474025596260355 @ 2022-01-07T15:24:29.000Z by Nasadox

# %%
for tweet in results.tweets.values():
    client.like(tweet.id)
# Out:
# [ 2022-01-11 16:14:37,914 ] tweepy.client (WARNING): Rate limit exceeded. Sleeping for 892 seconds.

# %%
def show_data(data):
    for key, val in data.items():
        if type(val)==dict:
            show_data(val)
        else:
            print(f"{key}: {val}\n")
show_data(tweet.data)
# Out:
# created_at: 2022-01-07T15:24:29.000Z
#
# id: 1479474025596260355
#
# author_id: 1048180379847258112
#
# conversation_id: 1479474025596260355
#
# reply_settings: everyone
#
# text: #ClimateStrike Week20
# This Year We must Ensure to do Best for Our Only Planet ❕
# More Sustainability🌎
# More Recycling♻
# More Plantation🌳
# Eco-Transportation🚍
# Saving Water💧
# No Single-Use Plastic❌
# Net Zero Actions ⚠
# #FridaysForFuture
# #twiff
# #ClimateActionNow ✊🏻
# @Recycle_ow https://t.co/sj0KJyGH4h
#
# mentions: [{'start': 260, 'end': 271, 'username': 'Recycle_ow', 'id': '1234904535652388864'}]
#
# hashtags: [{'start': 0, 'end': 14, 'tag': 'ClimateStrike'}, {'start': 211, 'end': 228, 'tag': 'FridaysForFuture'}, {'start': 230, 'end': 236, 'tag': 'twiff'}, {'start': 238, 'end': 255, 'tag': 'ClimateActionNow'}]
#
# urls: [{'start': 272, 'end': 295, 'url': 'https://t.co/sj0KJyGH4h', 'expanded_url': 'https://twitter.com/Nasadox_/status/1479474025596260355/photo/1', 'display_url': 'pic.twitter.com/sj0KJyGH4h'}]
#
# lang: en
#
# source: Twitter Web App

# %% [markdown]
# # Parsing

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
for tweet in list(results.tweets.values())[::-1]: 
    print(color.BOLD + '{} @ {} by {}' .format(tweet.id, tweet.created_at, results.users[tweet.author_id].name) + color.END)
    print(tweet.text)
    print('----------\n')
# Out:
# 1479474025596260355 @ 2022-01-07T15:24:29.000Z by Nasadox
# #ClimateStrike Week20
# This Year We must Ensure to do Best for Our Only Planet ❕
# More Sustainability🌎
# More Recycling♻
# More Plantation🌳
# Eco-Transportation🚍
# Saving Water💧
# No Single-Use Plastic❌
# Net Zero Actions ⚠
# #FridaysForFuture
# #twiff
# #ClimateActionNow ✊🏻
# @Recycle_ow https://t.co/sj0KJyGH4h
# ----------
#
# 1479422653572255745 @ 2022-01-07T12:00:21.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 1, #fridaysforfuture, Germany, Hamburg,
#
# https://t.co/NPwKTq6kYi
#
# https://t.co/uf4ybUUNF7
# ----------
#
# 1479383912484900866 @ 2022-01-07T09:26:25.000Z by Barbara Fischer
# James is back! The polluted polarbear prepared by @SpiritWandererX He demands our solidarity. #FridaysForFuture @FFFMapCount #Twiff, 6, #Germany Berlin 2022-01-07 Join our vigil from 10 to 12 to #MakeParisReal https://t.co/qGi0I3dhri
# ----------
#
# 1479373300019208196 @ 2022-01-07T08:44:14.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 1, #fridaysforfuture, Africa,, Lake Chad
# https://t.co/mZ5tiIKI4l https://t.co/icysYRmYPY
# ----------
#
# 1479370775543091201 @ 2022-01-07T08:34:12.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 2, #fridaysforfuture, Itay,,
# https://t.co/mZ5tiIKI4l https://t.co/fSi2yHxRcv
# ----------
#
# 1479370161606078466 @ 2022-01-07T08:31:46.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 7, #fridaysforfuture, UK,, 2022-01-06
# https://t.co/mZ5tiIKI4l https://t.co/ZlGw4o1l9V
# ----------
#
# 1479368870511136772 @ 2022-01-07T08:26:38.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 1, #fridaysforfuture, UK,, Telford
# https://t.co/mZ5tiIKI4l https://t.co/kOoV7EOfq8
# ----------
#
# 1479367839203139587 @ 2022-01-07T08:22:32.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you!
# Great to join so many #Solidarity!
#
# Nearly 900 places on around 80 countries!
#
# #twiff, 7, #fridaysforfuture, India,, New Delhi
# https://t.co/mZ5tiIKI4l https://t.co/u4mhfcVeiZ
# ----------
#
# 1479358880165552128 @ 2022-01-07T07:46:56.000Z by 💧 Janine Climate #UprootTheSystem
# As color blind politicians call nuclear and gas green, will the courts stand by science?
#
# Can we expect the power holders to be just non violence?
#
# #ClimateJustice!
# #ClimateEmergency!
#
# Week 177,
# @FFFMapCount
#
# #twiff, 2, #FridaysForFuture #Sweden,, Svedmyra, 2022-01-07 https://t.co/ow679BzHas
# ----------
#
# 1478692134974902273 @ 2022-01-05T11:37:32.000Z by 💧 Janine Climate #UprootTheSystem
# @LauraMuwanguzi @martinmcnulty @GretaThunberg Is there a voice which is less important?
#
# Thank you for making these important voices heard!
#
# #twiff, 30, #Fridaysforfuture, Uganda,, Kampala, 2021-01-04,
# https://t.co/2tkzpiN2LM
# ----------
#
# 1477214484754276353 @ 2022-01-01T09:45:53.000Z by 💧 Janine Climate #UprootTheSystem
# Solidarity @TomsTweeters!
#
# Every day #ClimateBreakdown makes our #ClimateEmergency road tougher!
#
# Respect and empathy for autonomous activism creates hope!
#
# #twiff, 1, #FridaysForFuture, Netherlands,,, 2021-12-31
# https://t.co/s0hsIJLk1G
# ----------
#
# 1476967914930679809 @ 2021-12-31T17:26:06.000Z by 💧 Janine Climate #UprootTheSystem
# @BeeAsMarine As less than 1% of humans destroy our climate and ecosystems for everyone!
#
# These 1% are the richest on our planet and they start with the ecosystems of the poorest 10% first!
#
# #twiff, 2, #FridaysForFuture #Sweden
# https://t.co/wqqCWoRx2N
# ----------
#
# 1476948328139169808 @ 2021-12-31T16:08:16.000Z by 💧 Janine Climate #UprootTheSystem
# @fischerdata @FFFMapCount @bella_linne @endelstamberg @AaravSeth_ @TomsTweeters @redmayne_robert @madlove_love @IsStratkotter @GryllsMaitreya @ClimateYamin Lots of great bots coming out!
#
# thank you! @TheSwedishBot, @michalspano, @FFFBot1, @amity_ak97,
#
# Please join us with the #twiff @twiff_bot
#
# all ideas are welcome!
#
# The #FFFMapCount team uses this Vision Proposal to join the team @FFFMapCount
#
# https://t.co/sZu0Vigu15
# ----------
#
# 1476945512809050114 @ 2021-12-31T15:57:05.000Z by 💧 Janine Climate #UprootTheSystem
# @ayowecca_uganda @UNFCCC @Fridays4future @GretaThunberg Nice work! Thank you!
#
# Will #twiff do its stuff?
#
# #twiff, 2, #FridaysForFuture, Uganda,, Tororo, 2021-12-31
# https://t.co/qH5OkXYovs
# ----------
#
# 1476943674068111399 @ 2021-12-31T15:49:46.000Z by 💧 Janine Climate #UprootTheSystem
# Thank you for your activism in 2021!
#
# Your activism gives me hope!
#
# Happy and Safe 2022!
#
# Can we expect the power holders to use just non violence?
#
# #ClimateJustice!
# #ClimateEmergency!
#
# Week 176,
# @FFFMapCount
#
# #twiff, 2, #FridaysForFuture #Sweden,, Svedmyra, 2021-12-31 https://t.co/zpJ95DB9oo
# ----------
#
# 1476872063654768641 @ 2021-12-31T11:05:13.000Z by Tom #FFFMapCount💚🌍🌎🌏💚
# #twiff,1,#FFFMapCount,Philippines,,,2021-12-31,https://t.co/6kLPiIR1ay
# ----------
#
# 1476868574216011776 @ 2021-12-31T10:51:21.000Z by Nasadox
# #ClimateStrike Week19
# Another Year passed but
# What we got!!**
# What we Lost ?
# 🌳🌎♻
# #FridaysForFuture
# #UprootTheSystem
# #ClimateCrisis
# #ClimateAction
# #ClimateJustice
# #twiff
# @Recycle_ow
# @CCCAAZambia
# @fff_whk
# @FFFPunjab
# @FFFMapCount
# @XRRebelEveryDay
# @ExtinctionR_DE https://t.co/Fkez27gs3x
# ----------
#
# 1476864235862958111 @ 2021-12-31T10:34:07.000Z by Barbara Fischer
# #FridaysForFuture finally some more people join us. Here some girls from Aachen to #MakeParisReal #Twiff #ClimateAction https://t.co/jqZyNTed4o
# ----------
#
# 1476851470318379026 @ 2021-12-31T09:43:23.000Z by Barbara Fischer
# The last day of the year is not the last #FridaysForFuture  We are here @Bundestag as long as it takes to #MakeParisReal #Twiff https://t.co/ARzdqq03Kx
# ----------
#
# 1476833103880597504 @ 2021-12-31T08:30:24.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Week 29 #ClimateStrike in #Angola
# Today in Streets
# #ClimateActionNow
# #FridaysForFuture
# #UprootTheSystem
# #NetZero
# #twiff [1], [F4FAO], [Cassequel], [31,12,2021] https://t.co/s1kMFL4cJA
# ----------
#
# 1476830531660754944 @ 2021-12-31T08:20:11.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Week 29 #ClimateStrike in #Angola
# Today I went to the streets motivated, strike for the climate and enjoy the moment. Take action on the climate, we don't want to eat coal and drink oil.
#
# #FridaysForFuture
# #UprootTheSystem
# #NetZero
# #twiff [1], [F4FAO], [Cassequel], [31,12,2021] https://t.co/CX8pcRyzvp
# ----------
#
# 1476702297862377476 @ 2021-12-30T23:50:38.000Z by Barbara Fischer
# #DontLookUp Es ist wieder Freitag. Von 10 bis 12 Mahnwache für das #ParisAgreement vor dem Bundestag. Wie immer #FridaysForFuture #twiff #ClimateAction Wenn die Politik doch endlich loslegte, das ist mein Hoffnungsträumen für 2022. Schaut den Film, er bringt es auf den Punkt ➡️ https://t.co/G8j6K0fHg9
# ----------
#
# 1476294800123076609 @ 2021-12-29T20:51:23.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# #twiff, test
# ----------
#
# 1475936120265445377 @ 2021-12-28T21:06:07.000Z by 💧 Janine Climate #UprootTheSystem
# @Global_Witness @FFFUnitedStates Our system is broken and this speech explains how to see this very well!
#
# Thank you!
#
# #twiff, 2, #FridaysForFuture, USA,,, 2021-11-09
# https://t.co/8AZv7ajpNL
# ----------
#
# 1475789543785877508 @ 2021-12-28T11:23:40.000Z by 💧 Janine Climate #UprootTheSystem
# How precious is activism?
#
# If historical Prophets were also using non violence for justice, like #ClimateJustice, how important is Your activism? 😇
#
#  #ClimateEmergency
#
# Week 175,
# Mynttorget @FFFMapCount
#
# #twiff, 2, #FridaysForFuture #Sweden,, Svedmyra, 2021-12-24 https://t.co/NLgm3bwNrc
# ----------
#
# 1474351985981804549 @ 2021-12-24T12:11:20.000Z by Barbara Fischer
# #ClimateAction #Twiff 5 people in Berlin https://t.co/gwA41N2T1a
# ----------
#
# 1474351793379454979 @ 2021-12-24T12:10:34.000Z by Barbara Fischer
# #ClimateAction #Twiff 3 people in Berlin https://t.co/S07JX8wvOn
# ----------
#
# 1474351677675348000 @ 2021-12-24T12:10:06.000Z by Barbara Fischer
# #ClimateAction #Twiff 5 people in Berlin https://t.co/mGQp9QXfr0
# ----------
#
# 1474313058134761475 @ 2021-12-24T09:36:39.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# #Schoolstrike #week 28 in #Angola. Scientists can prove it. The world is focused on the wrong thing, the climate crisis exists and it is a crisis.
# #FridaysForFuture #ClimateStrike #UprootTheSystem
# #SaveGambos
# #SosCuneneAngola
# #twiff [1], [F4FAO], [Maianga], [24,12,2021] https://t.co/B67fQMwkzp
# ----------
#
# 1473576395166998532 @ 2021-12-22T08:49:24.000Z by @Twiff_bot 🌏 #Twiff
# @JanineClimate @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubarak @WinnieCheche @Martelocris @ImandiU @EmaanzT @madlove_love @TomsTweeters @chanchaljangir9 @KabilaObbo @DenisNishant @Andrew88820142 @krosenlund_com @VikashBalmuchu @endelstamberg @GeraldKutney @WakioDorcas Thanks @JanineClimate for your climate action 🌏 and using #twiff!
#
# I wasn't able to extract any fields from your tweet! 😢
#
# To have your action registered please reply using the following format: #twiff [Number of People], [Organization], [Location], [Datetime]
# ----------
#
# 1473576069512921093 @ 2021-12-22T08:48:07.000Z by @Twiff_bot 🌏 #Twiff
# @JanineClimate @act_nowclimate @nzlabour @NZNationalParty @GretaThunberg @FFFMapCount @TomsTweeters Thanks @JanineClimate for your climate action 🌏 and using #twiff! 😁
#
# People: 2
# Org: climateaction
# Location: nz, goughs, bay
# Date: 2021-12-20
#
# If any fields are incorrect please reply using the following format: #twiff [Number of People], [Organization], [Location], [Datetime]
# ----------
#
# 1473006074148147202 @ 2021-12-20T19:03:09.000Z by 💧 Janine Climate #UprootTheSystem
# @act_nowclimate @nzlabour @NZNationalParty @GretaThunberg I wish I could say, I am glad you are safe, but I feel only able to say, 'I am glad you are safe for now!'
#
# Welcome aboard!
#
# Your #ClimateAction is needed!
#
# @FFFMapCount @TomsTweeters
# #twiff, 2, #ClimateAction, NZ,, Goughs Bay, 2021-12-20
# https://t.co/UKzru5qfzv
# ----------
#
# 1472884160268283907 @ 2021-12-20T10:58:43.000Z by Fridays For Future AO #UprootTheSystem
# In Angola
#
# @fffmapcount
#
# @twiff
#
# #twiff, 1, #FridaysForFuture, Angola, Luanda, Maianga 2021-12-17 https://t.co/dCWOYq1giH
# ----------
#
# 1472883409978593280 @ 2021-12-20T10:55:44.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# @Greenpeace #twiff 1, #FridaysForFuture, Angola, Maianga, Luanda, 2021-12-17
# ----------
#
# 1472315758680100864 @ 2021-12-18T21:20:05.000Z by 💧 Janine Climate #UprootTheSystem
# As we wait for the ice to break, &amp; you wish for #ClimateJustice for #Xmas, who shall respond?
#
# If they are inactive, will you use Non Violent Direct Action?
#
# #ClimateEmergency
#
# #twiff, 6, #SaturdaysForFuture, Sweden Stockholm, #Medborgarplasten, 2021-12-18 https://t.co/8FNN0wkHqd
# ----------
#
# 1472148726798077952 @ 2021-12-18T10:16:22.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# @NidaKirmani @vanessa_vash @auber_fichess @GretaThunberg @isabelle_ax @EllJarl @AldeFermskog @shylacherop @Luisamneubauer @ayowecca_uganda @MichalGrzywa @ShikhaSeth17 @AaravSeth_ @FinlayPringle @JanineClimate @MayaOzbayoglu @KertuAnton @LauraMuwanguzi @Fridays4FutureU Thank you for your #ClimateStrike @ForFutureRM,
# Report action on the map using the Fridays for Future twitter bot.
# Format is: #twiff, number of people, organisation, country, state/province, city
# #twiff,13,#FFFMapCount,Nederland,Limburg,Roermond,2021-12-18,https://t.co/1Gr7Rxskhn
# ----------
#
# 1472145220997373952 @ 2021-12-18T10:02:26.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# @NidaKirmani @vanessa_vash @auber_fichess @GretaThunberg @isabelle_ax @EllJarl @AldeFermskog @shylacherop @Luisamneubauer @ayowecca_uganda @MichalGrzywa @ShikhaSeth17 @AaravSeth_ @FinlayPringle @JanineClimate @MayaOzbayoglu @KertuAnton @LauraMuwanguzi Thank you for your #ClimateStrike @Fridays4FutureU,
# Report your action on the map using the Fridays for Future twitter bot.
# Format is: #twiff, number of people, organisation, country, state/province, city
# #twiff,35,#FFFMapCount,Uganda,,,2021-12-18,https://t.co/yJt9F6mCQr
# ----------
#
# 1472144756063064066 @ 2021-12-18T10:00:35.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# @NidaKirmani @vanessa_vash @auber_fichess @GretaThunberg @isabelle_ax @EllJarl @AldeFermskog @shylacherop @Luisamneubauer @ayowecca_uganda @MichalGrzywa @ShikhaSeth17 @AaravSeth_ @FinlayPringle @JanineClimate @MayaOzbayoglu @KertuAnton Thank you for your #ClimateStrike @LauraMuwanguzi,
# Report your action on the map using the Fridays for Future twitter bot.
# Format is: #twiff, number of people, organisation, country, state/province, city
# #twiff,2,#FFFMapCount,Uganda,,Kampala,2021-12-18,https://t.co/qGcfBILUjr
# ----------
#
# 1472144257419030530 @ 2021-12-18T09:58:36.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# @NidaKirmani @vanessa_vash @auber_fichess @GretaThunberg @isabelle_ax @EllJarl @AldeFermskog @shylacherop @Luisamneubauer @ayowecca_uganda @MichalGrzywa @ShikhaSeth17 @AaravSeth_ @FinlayPringle @JanineClimate @MayaOzbayoglu Thank you for your #ClimateStrike @KertuAnton,
# Report your action on the map using the Fridays for Future twitter bot.
# Format is: #twiff, number of people, organisation, country, state/province, city
# #twiff,1,#FFFMapCount,Eestis,,,2021-12-18,https://t.co/MT5FXC6hvt
# ----------
#
# 1472143800512438282 @ 2021-12-18T09:56:47.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# @NidaKirmani @vanessa_vash @auber_fichess @GretaThunberg @isabelle_ax @EllJarl @AldeFermskog @shylacherop @Luisamneubauer @ayowecca_uganda @MichalGrzywa @ShikhaSeth17 @AaravSeth_ @FinlayPringle @JanineClimate Thank you for your #ClimateStrike @MayaOzbayoglu,
# Report your action on the map using the Fridays for Future twitter bot.
# Format is: #twiff, number of people, organisation, country, state/province, city
# #twiff,1,#FFFMapCount,Poland,,,2021-12-18,https://t.co/n9knCk0AUa
# ----------
#
# 1471971600027336708 @ 2021-12-17T22:32:32.000Z by 💧 Janine Climate #UprootTheSystem
# @fischerdata @SpiritWandererX @Bundestag @FFFMapCount @twiff @TomsTweeters @DawnRoseTurner exactly!
#
# The bot is still in training!
#
# The formula is:
# #twiff, 7, #Fridaysforfuture, Germany,, Berlin, 2021-12-17, (URL)
# ----------
#
# 1471971031560691727 @ 2021-12-17T22:30:16.000Z by 💧 Janine Climate #UprootTheSystem
# @TomsTweeters @FFFMapCount @FFF_SAJ @Leyse65081133 @endelstamberg @Steffenster @fischerdata @stefangsaenger @WeNaturalists @NayonSorkarBD @twongirwe_ireen @YGCUganda @ThieSabine @WWindEA @wiligl @ExtinctionR_SV @Thakrarkhelan @redmayne_robert @VipinSangwanVS @arifismail0 @voicetopeople @yamunajiye @rwclimate @ShreyaTuli_ @IvyKriss @WakioDorcas @mrEmTee @thekopargaonkar @DenisNishant @ArunYadav0007 @sachinjacobk @parents4future @JovanMaria123 @madlove_love @fridays_india @releaf4us @SwedishPM @fff_sssat @AdamSrigley @arhogan @ArubaFaruque @Mrs_Dalloway_ @fff_tui @AnnaTermine2 @BespokePanic @bella_linne @Shell @IPCC_CH Were historical Prophets also using non violence for justice?
#
# How many Prophets and angels, did you meet today, working for #ClimateJustice? 😇
#
#  #ClimateEmergency
#
# Week 174, 2021-12-17
# Kungsholmen
# @FFFMapCount
#
# #twiff, 5, #FridaysForFuture #Sweden,, Kungsholmen, 2021-12-17 https://t.co/m8LdEm0h98
# ----------
#
# 1471968708285415428 @ 2021-12-17T22:21:02.000Z by 💧 Janine Climate #UprootTheSystem
# @SpiritWandererX @fischerdata @Bundestag You are truly amazing! Thank you!
#
# @fffmapcount @twiff @TomsTweeters @DawnRoseTurner
#
# #FridaysForFuture #ClimateStrike
# #twiff, 7, #Fridaysforfuture, Germany,, Berlin, 2021-12-17,
# https://t.co/ebqCuhI68c
# ----------
#
# 1471950743167021066 @ 2021-12-17T21:09:39.000Z by 💧 Janine Climate #UprootTheSystem
# @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubarak @WinnieCheche @Martelocris @ImandiU @EmaanzT @madlove_love @TomsTweeters @chanchaljangir9 @KabilaObbo @DenisNishant @Andrew88820142 @krosenlund_com @VikashBalmuchu @endelstamberg @GeraldKutney @WakioDorcas As we work together our voices gain momentum and we are unstoppable!
#
# #Solidarity #ClimateStrike #FridaysForFuture
# #twiff
#
# https://t.co/nUFeMqW7FY
# ----------
#
# 1471950074053906439 @ 2021-12-17T21:06:59.000Z by 💧 Janine Climate #UprootTheSystem
# @ImandiU @tonytheauthor @KambojAnanya @BeeAsMarine @KaoHua3 @AaravSeth_ @ZillionTree @human @BhupalPsr @AlmuthSiegl @TonyHussein4 @Vinnisha8848 @endelstamberg @UNOCHA @Sdg13Un @UNESCO Thank you!
#
# #Solidarity #ClimateStrike #FridaysForFuture
# #twiff
#
# https://t.co/nUFeMqW7FY
# ----------
#
# 1471949423521714176 @ 2021-12-17T21:04:24.000Z by 💧 Janine Climate #UprootTheSystem
# @AaravSeth_ @arifismail0 @mnyomb1 @Anushka_nature @IvyKriss @WakioDorcas @mrEmTee @Thakrarkhelan @DenisNishant @TorstenLuetten @VikashBalmuchu @thekopargaonkar @JovanMaria123 @Riseupmovt @kaynair @JosephusLudwig @RamprakashMina @lifelearner47 @gautamluhar2 This is the work of angels!
#
# #Solidarity #ClimateStrike #FridaysForFuture
# #twiff
#
# https://t.co/nUFeMqWFvw
# ----------
#
# 1471948902865772559 @ 2021-12-17T21:02:20.000Z by 💧 Janine Climate #UprootTheSystem
# @endelstamberg @nataliebookout @moreau_doc @essennique @LeoOni1 @anastasiaserg2 @asyafomina_ru @LubYo @MakichyanA @weeAnarchist @emma_ymp @lilliasworld @raiganl314 @RonaldOnyang1 @mnyomb1 @Manukabila0 @edwinNamakanga @DenisNishant @superestribillo Excellent thank you!
#
# #Solidarity #ClimateStrike #FridaysForFuture
# #twiff
#
# https://t.co/nUFeMqW7FY
# ----------
#
# 1471939938757353481 @ 2021-12-17T20:26:43.000Z by 💧 Janine Climate #UprootTheSystem
# @FFF_SAJ @FFFMapCount @Leyse65081133 @endelstamberg @Steffenster @fischerdata @stefangsaenger @WeNaturalists @NayonSorkarBD @twongirwe_ireen @YGCUganda @TomsTweeters @ThieSabine @WWindEA @wiligl @ExtinctionR_SV @Thakrarkhelan @redmayne_robert @VipinSangwanVS @arifismail0 @voicetopeople @yamunajiye @rwclimate @ShreyaTuli_ @IvyKriss @WakioDorcas @mrEmTee @thekopargaonkar @DenisNishant @ArunYadav0007 @sachinjacobk @parents4future @JovanMaria123 @madlove_love @fridays_india @releaf4us @SwedishPM @fff_sssat @AdamSrigley @arhogan @ArubaFaruque @Mrs_Dalloway_ @fff_tui @AnnaTermine2 @BespokePanic @bella_linne @Shell In only a few years, we went from Sustainability to #ClimateEmergency, with all life systems threatened!
#
# How quick is the next step? 😬 @IPCC_CH
#
# Week 174, 2021-12-17
# Stockholm
# With @releaf4us &amp; Dario!
# @FFFMapCount
#
# #twiff, 7, #FridaysForFuture #Sweden,,Svedmyra, 2021-12-17 https://t.co/DMFr5zbFPk
# ----------
#
# 1471925765642063881 @ 2021-12-17T19:30:24.000Z by 💧 Janine Climate #UprootTheSystem
# @FFFSuomi Wonderful! Your Back! Thank you!
#
# @fffmapcount @twiff @TomsTweeters @DawnRoseTurner
#
# #FridaysForFuture #ClimateStrike
# #twiff, 19, #Fridaysforfuture, Finland,, Helsinki, 2021-12-17,
# https://t.co/mpSHvosXoZ
# ----------
#
# 1471924280044703757 @ 2021-12-17T19:24:30.000Z by 💧 Janine Climate #UprootTheSystem
# @AaravSeth_ @RahulGandhi @HansrajMeena @NewIndianXpress @GretaThunberg @NaomiAKlein @KaoHua3 @ndtv @CBSNews @PamelaFalk @thekopargaonkar @wcco4climate @KambojAnanya @vanessa_vash @Martelocris @CrissyNankya Amazing Courage, thank you!
#
# @fffmapcount @twiff
# #twiff, 3, ##forests, India,, Auroville, 2021-12-17, https://t.co/nG7JcIywgX
# ----------
#
# 1471923428072509450 @ 2021-12-17T19:21:06.000Z by 💧 Janine Climate #UprootTheSystem
# @FFFPunjab @KambojAnanya @KambojAahana @GryllsMaitreya @GretaThunberg @vanessa_vash @Farah_mkma @sophiamathur @CevikusHB @AaravSeth_ @ap4ca @FFFIndia @ExtinctionR @mrEmTee @NakabuyeHildaF @eve_chantel @parents4future @Fridays4FutureU @WakioDorcas @TomsTweeters @KabilaObbo @redmayne_robert Wonderful to see, thank you!
#
# @fffmapcount @twiff
# #twiff, 4, #FridaysForFuture, India, Punjab,, 2021-12-17, https://t.co/zexnZJrV6C
# ----------
#
# 1471922072213499917 @ 2021-12-17T19:15:43.000Z by 💧 Janine Climate #UprootTheSystem
# @ShikhaSeth17 @GretaThunberg @vanessa_vash @rwclimate @KaoHua3 @Fridays4future @FFFIndia @ExtinctionR @Luisamneubauer @NaomiAKlein @NakabuyeHildaF @WakioDorcas @charlotteauman1 @mnyomb1 @KabilaObbo @SteveMisatih @endelstamberg @GeraldKutney @redmayne_robert @TomsTweeters @FFFMAPA Great work, thank you!
#
# #twiff, 4, #FridaysForFuture, India,, Dehli, 2021-12-17, https://t.co/ytoUDiMZYD
# ----------
#
# 1471921382233714697 @ 2021-12-17T19:12:59.000Z by 💧 Janine Climate #UprootTheSystem
# @MichalGrzywa @FFFMAPA @vanessa_vash @Fridays4future @GeraldKutney @ExtinctionR @GretaThunberg @msklimatyczny @parents4future @XRebellionUK Excellent to see, thank you!
#
# #twiff, 1, #Climatestrike, Poland,, Lancut, 2021-12-17, https://t.co/s0P5Vtv8bv
# ----------
#
# 1470821530414243840 @ 2021-12-14T18:22:34.000Z by 💧 Janine Climate #UprootTheSystem
# @AufstandLastGen Well done!
#
# #twiff, 10, #LastGeneration, Germany,,, 2021-12-14, https://t.co/9IvRiwcxRU
# ----------
#
# 1470370904148488196 @ 2021-12-13T12:31:56.000Z by 💧 Janine Climate #UprootTheSystem
# @auber_fichess @factosdabanda Do you what #twiff is for?
#
# #Twiff is learning how to automatically put your tweets on the #FridaysForFutuer #FFFMapCount!
#
# Working with  @twiff @fffmapcount
#
# #twiff 🌏 2, #FridaysForFuture, Angola, Cassequel, Luanda, 2021-10-15, https://t.co/z4pxX8RASo
# ----------
#
# 1470362662198554626 @ 2021-12-13T11:59:11.000Z by 💧 Janine Climate #UprootTheSystem
# @auber_fichess @factosdabanda Nice work, do you want to give an approximate location?
#
# If so please add it to the commas
#
# #twiff 2, #FridaysForFuture, Country, Region, Town, 2021-10-15, https://t.co/z4pxX8RASo
# ----------
#
# 1470200239760068613 @ 2021-12-13T01:13:46.000Z by Mario Lanza
# #twiff 🙃🙃🙃 ♥️ https://t.co/oxAMuGRrIV
# ----------
#
# 1469956781208223746 @ 2021-12-12T09:06:21.000Z by 💧 Janine Climate #UprootTheSystem
# @fff_tui @FFFLimerick @FFF_Aus @FFFDresden @FFF_Tokyo @fff_europe @FFFUnitedStates @FFFIndia @FFFCanada @fff_Sydney @FFFRussia @GretaThunberg Great to see! Thank you!
#
# Time to #twiff 6, #Fridaysforfuture, New Zealand,, Wellington
# https://t.co/lDOsyfTn7K
# ----------
#
# 1468572384340983813 @ 2021-12-08T13:25:15.000Z by @Twiff_bot 🌏 #Twiff
# Thank you for your Climate Activism!
# &amp; for calling 🌏 #Twiff !
# An automated robot experimenting how to 🌏 #Twiff direct to the #FFFMapCount !
# #twiff [Number of people], [Organisation], [Country], [State], [Town]
# E.g. #twiff 16, FFFMapCount, Netherlands, Noord-Brabant, Breda.
# ----------
#
# 1467878798150488066 @ 2021-12-06T15:29:12.000Z by 💧 Janine Climate #UprootTheSystem
# @Sdg13Un @RMBlaber56 @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Is adaptation enough or do we need mitigation?
#
# What technologies do we have for mitigation?
#
# Can we reduce #ClimateEmergency by ignoring it?
#
# #twiff, 1, #FFFMapCount, Germany,, Berlin
# https://t.co/H0EMUHc4Bb
# ----------
#
# 1467827378642694147 @ 2021-12-06T12:04:52.000Z by 💧 Janine Climate #UprootTheSystem
# @sustainme_in @FFFMapCount @krosenlund_com Our soils are dying, can we see this?
#
# Does the life in the soil use #MutualCooperation?
#
# Does #Dought remove life from the soil?
#
# Does #ClimateEmergency destroy soil?
#
# #twiff 2, FFFMapCount, USA, MA, Cambridge
# https://t.co/lYRFWL90OV
# ----------
#
# 1467825346791759872 @ 2021-12-06T11:56:48.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl @DoemenR Will the beauty of nature be enough to convince the #FossilFuels?
#
# Our #ClimateEmergency is made by the few, for the few, of the few!
#
# #twiff 2, FFFMapCount, France,, Toulouse
# https://t.co/45U6vKVjxU
# ----------
#
# 1467818568754634758 @ 2021-12-06T11:29:52.000Z by 💧 Janine Climate #UprootTheSystem
# @FFF_SAJ @FFFMapCount @Leyse65081133 @endelstamberg @Steffenster @fischerdata @stefangsaenger @WeNaturalists @NayonSorkarBD @twongirwe_ireen @YGCUganda @TomsTweeters @ThieSabine @WWindEA @wiligl @ExtinctionR_SV @Thakrarkhelan @redmayne_robert @VipinSangwanVS @arifismail0 @voicetopeople @yamunajiye @rwclimate @ShreyaTuli_ @IvyKriss @WakioDorcas @mrEmTee @thekopargaonkar @DenisNishant @ArunYadav0007 @sachinjacobk @parents4future @JovanMaria123 @madlove_love @fridays_india @releaf4us @SwedishPM @fff_sssat @AdamSrigley @arhogan @ArubaFaruque @Mrs_Dalloway_ @fff_tui @AnnaTermine2 @BespokePanic @bella_linne @Shell @WWF @AfiegoUg Does the weather creating a rain for a drought or a strong cold snap mean our #ClimateEmergency is over?
#
# #twiff, 13, SaturdaysForFuture #Sweden,, Medborgarplatsen, 2021-12-04 https://t.co/37PaUznmHV
# ----------
#
# 1467814415185727493 @ 2021-12-06T11:13:21.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl @DoemenR Do you want to understand #Twiff?
#
# #twiff 4, FFFMapCount, India,, Delhi
# #twiff (people:4), (organisation:FFFMapCount), (Location:Country,State,Town:India,, Delhi)
#
# https://t.co/BoCssQz9Xi
# ----------
#
# 1467813536349003776 @ 2021-12-06T11:09:52.000Z by 💧 Janine Climate #UprootTheSystem
# @sustainme_in @FFFMapCount @krosenlund_com Is the #FFFMapCount a from of #MutualCooperation?
#
# #Dought has shown us #ClimateEmergency for decades!
#
# #twiff 4, FFFMapCount, India,, Delhi
# https://t.co/ZMcfs12kl8
# ----------
#
# 1467811401586642946 @ 2021-12-06T11:01:23.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Can we win without #trees and #forests ?
#
# #Ecocide #ClimateEmergency #FFFMapCount counted!
#
# #twiff 1, FFFMapCount, Germany, 2021-12-05
#
# https://t.co/0AGVXMbp6t
# ----------
#
# 1467810539652980741 @ 2021-12-06T10:57:57.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl What does democracy look like?
#
# #Ecocide #ClimateEmergency #FFFMapCount counted!
#
# #twiff 1, FFFMapCount, Germany,, Hamburg, 2021-12-03
# https://t.co/aODIHCInGe
# ----------
#
# 1467809152600789028 @ 2021-12-06T10:52:27.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Can we win without #MutualCooperation?
#
# #Ecocide #ClimateEmergency #FFFMapCount counted!
#
# #twiff 6, FFFMapCount, Sweden, Gustavsberg
# Date: 2021-12-03
# https://t.co/8WMY2q5340
# ----------
#
# 1467807940262477825 @ 2021-12-06T10:47:38.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Excellent post!
#
# #Ecocide #ClimateEmergency #FFFMapCount counted!
#
# #twiff 1, FFFMapCount, USA, MA, Cambridge
# https://t.co/LHUOd9gqWb
# ----------
#
# 1467806531311788040 @ 2021-12-06T10:42:02.000Z by 💧 Janine Climate #UprootTheSystem
# @RMBlaber56 @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Excellent work! With #MutualCooperation we are #StrongerTogether
#
# Dec 3 Week 172
# Strikes 906 (up from 882)
# Countries 83 (up from 81)
#
# #UprootTheSystem
# #FridaysForFuture
# #ClimateStrike
#
# #twiff 10, FFFMapCount, Sweden, Vännäs
# https://t.co/OukBPDlKiB
# ----------
#
# 1467578842399313926 @ 2021-12-05T19:37:16.000Z by 11thHFC
# #twiff Ewhurst, Cranleigh, UK: 2021-12-02, 2 striking for #11thHourForClimate with #FridaysForFuture
# ----------
#
# 1467450340341653508 @ 2021-12-05T11:06:39.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# #twiff
# Date:2021-12-03
# People:25
# Org:FFFMapCount
# Country:Bangladesh
# Town:Dhaka
# URL:https://t.co/41x6x7sw3R
# ----------
#
# 1467448015384371200 @ 2021-12-05T10:57:25.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# #twiff 400, FFFMapCount, Deutschland, Aachen https://t.co/0jHiwtBaDP
# ----------
#
# 1467446392125861890 @ 2021-12-05T10:50:58.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# #twiff 1, FFFMapCount, India, Mohali https://t.co/4HFJBqvUPl
# ----------
#
# 1466894039224045578 @ 2021-12-03T22:16:07.000Z by @FFF_SAJ ._. Sweden Årsta Janine #UprootTheSystem
# @Vikrant_sri29 @redmayne_robert @narendramodi @BBCWorld @UN @UNYouthEnvoy @UNEP @byadavbjp @COP26 @MockCOP26 Great work!
#
# Thank you!
#
# this is a #Twiff!
# ----------
#
# 1466888367480651788 @ 2021-12-03T21:53:34.000Z by 💧 Janine Climate #UprootTheSystem
# @DawnRoseTurner @NayonSorkarBD @GretaThunberg @SwedenAmbBD @SaveFutureBd @Fridays4future @UNEP_Europe @UNBiodiversity @WWF @saberhc @SwissAmbBD @UNICEFBD @TomsTweeters Is #ClimateEmergency born of the rich, by the rich, for the rich?
#
# Thank you for your work! #FridaysforFuture #twiff
# Standing with you in every word!
# https://t.co/8WMY2q5340
# ----------
#
# 1466887738452496384 @ 2021-12-03T21:51:04.000Z by 💧 Janine Climate #UprootTheSystem
# @ShikhaSeth17 @GretaThunberg @vanessa_vash @KaoHua3 @Fridays4future @FFFIndia @FFFMAPA @parents4future @rwclimate @WakioDorcas @charlotteauman1 @endelstamberg @ExtinctionR @redmayne_robert @TomsTweeters @ErikSolheim @GeraldKutney Is our #ClimateEmergency a form of legal hate to us, our future and all of nature?
#
# Is it born of the rich, by the rich, for the rich?
#
# Thank you for your work! #FridaysforFuture #twiff
# Standing with you in every word!
# https://t.co/8WMY2q5340
# ----------
#
# 1466885984994349057 @ 2021-12-03T21:44:06.000Z by 💧 Janine Climate #UprootTheSystem
# @FFF_SAJ @FFFMapCount @Leyse65081133 @endelstamberg @Steffenster @fischerdata @stefangsaenger @WeNaturalists @NayonSorkarBD @twongirwe_ireen @YGCUganda @TomsTweeters @ThieSabine @WWindEA @wiligl @ExtinctionR_SV @Thakrarkhelan @redmayne_robert @VipinSangwanVS @arifismail0 @voicetopeople @yamunajiye @rwclimate @ShreyaTuli_ @IvyKriss @WakioDorcas @mrEmTee @thekopargaonkar @DenisNishant @ArunYadav0007 @sachinjacobk @parents4future @JovanMaria123 @madlove_love @fridays_india @releaf4us @SwedishPM @fff_sssat @AdamSrigley @arhogan @ArubaFaruque @Mrs_Dalloway_ @fff_tui @AnnaTermine2 @BespokePanic @bella_linne @Shell @WWF @AfiegoUg Dec 3, Week 172
#
# #Gustavsberg #Stockholm
# #Amazon's, #Shell's &amp; more greed creates
# #ClimateBreakdown #Poverty #Inequality
#
# How many deaths is #ClimateEmergency  creating NOW?
#
# Politicians say #2050 #BlahBlahBlah
#
# #FridaysForFuture
# #ClimateStrike
# #UprootTheSystem #twiff https://t.co/LgKoU75LhH
# ----------
#
# 1466437155765563412 @ 2021-12-02T16:00:37.000Z by 💧 Janine Climate #UprootTheSystem
# @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @RMBlaber56 @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl This needs counting!
#
# @lillyspickup has been regularly striking for a long long time!
#
# #FFFMapCount! #FridaysforFuture #twiff #ClimateStrike
# https://t.co/1hdatKO8Fn
# ----------
#
# 1466118638562426881 @ 2021-12-01T18:54:57.000Z by 💧 Janine Climate #UprootTheSystem
# @SDO_Org Thanks for your #ClimateAction &amp; using #Twiff
# No pre reg found
# Date:2021-11-29
# People:1
# Org:FFFMapCount
# Country: Pakistan
# State:
# Town:  Islamabad
# URL:https://t.co/CfbyOasva0
# If the above is incorrect, copy reply and correct please
# ----------
#
# 1466117777136050177 @ 2021-12-01T18:51:31.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# #FridayaysForFuture #MapCount Meeting
# Thank you all for your work!
#
# #twiff 4, FFFMapCount, Svedmyra, Stockholm, Sweden https://t.co/PZQK0rZuuu
# ----------
#
# 1466075160843276298 @ 2021-12-01T16:02:11.000Z by 💧 Janine Climate #UprootTheSystem
# @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @RMBlaber56 @Sdg13Un @fromjimbarnes @FFFMapCount @Thakrarkhelan @MarineGOfficial @DawnRoseTurner @FFF_Jour @Vinnisha8848 @endelstamberg @FFF_SAJ @kathleenmartsch @jojoju15 @arty_gital @monopolsiedler @luckmann2008 @XR_Aufstand @fischerdata @Alexand99589931 @voicetopeople @arifismail0 @redmayne_robert @Jnwamson @Ros_Rodriguez_ @shantaw_nur @AnthonyGleeson4 @DenisNishant @Resistance411 @ECOWARRIORSS @Panachevert @Mrs_Dalloway_ @ArubaFaruque @howey_ou @BucketHatAlice @j_olwenyi @_carbontiptoes @Rise4Climate @leo_jiboiana @espiritomundo @saskiabricmont @ActionOn_Amazon @ProgIntl Thanks for your #ClimateAction &amp; using #Twiff
# No pre reg found
# Date:2021-12-01
# People:1
# Org:FFFMapCount
# Country:India
# State:
# Town:
# URL:https://t.co/Rfm3YkfFli
# If the above is incorrect, copy reply and correct please
# ----------

# %%
import re
def remove_emoji(string):
    emoji_pattern = re.compile("["
      u"\U0001F600-\U0001F64F"
      u"\U0001F300-\U0001F5FF"
      u"\U0001F680-\U0001F6FF"
      u"\U0001F1E0-\U0001F1FF"
      u"\U00002500-\U00002BEF"
      u"\U00002702-\U000027B0"
      u"\U000024C2-\U0001F251"
      u"\U0001f926-\U0001f937"
      u"\U00010000-\U0010ffff"
      u"\u2640-\u2642"
      u"\u2600-\u2B55"
      u"\u200d"
      u"\u23cf"
      u"\u23e9"
      u"\u231a"
      u"\ufe0f"
      u"\u3030"
      "]+", flags = re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\samca\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from arcgis.gis import GIS
from nltk.corpus import words

setofwords = set(words.words())

# %% [markdown]
# ## Strict Parsing

# %%
import re
import time
import datetime
import torchtext
import dateparser

# %%
user = client.get_user(username='twiff_bot')['data']
print(user)
# Out:
# {'id': '1466484534430547976', 'name': '@Twiff_bot 🌏 #Twiff', 'username': 'twiff_bot'}

# %%
valid_count = 0

strict_parse = False
attempt_clean_url_entities = True

organization_list = []
times = []

for idx, (key, tweet) in enumerate(list(results.tweets.items())[::-1]):
    start_time = time.time()
    could_parse = False 
    
    print(idx)
    print(color.BOLD + '{} @ {} by {}' .format(tweet.id, tweet.created_at, results.users[tweet.author_id].name) + color.END)
    
    if tweet.author_id==user['id']:
        print(color.RED + 'This tweet way made by {} not by an external user!'.format(user['name']) + color.END)
    
    # Clean up entities
    url_start_idx = tweet.entities['urls'][0]['start'] if 'urls' in tweet.entities and attempt_clean_url_entities else -1
    
    # Clean text
    text = tweet.text[:url_start_idx].strip().lower()
    text = remove_emoji(text)
    text = re.sub('[,:;(){}##/?@!.\[\]&%$*^\+=|<>`~"\']', ' ', text)
    text = re.sub('  ', ' ', text)
    
    # Tokenize the text (could also split but less reliable)
    tokens = torchtext.data.get_tokenizer("basic_english")(text)    
    
    twiff_idxs = [idx for (idx, token) in enumerate(tokens) if token=='twiff']
    
    for idx in twiff_idxs:
        if idx+1<len(tokens):
            try:
                int(tokens[idx+1])
                tokens = tokens[idx+1:]
                valid_count += 1
                
                # Parse number of people: Can verify
                num_people = int(tokens[0])
                del tokens[0]
                
                # Parse datetime
                inferred_datetime = False
                for idx, token in enumerate(tokens): 
                    date = dateparser.parse(token, settings={'STRICT_PARSING':True})
                    if date is not None:  
                        inferred_datetime = True
                        del tokens[idx]
                        break
                if date is not None:
                    date = color.GREEN + '{}'.format(date) + color.END
                else:
                    date = color.YELLOW + '{}'.format(datetime.datetime.strptime(tweet.created_at, '%Y-%m-%dT%H:%M:%S.%fZ')) + color.END
                    
                # Extract organization
                organization = tokens[0]
                organization_list.append(organization)
                del tokens[0]

                # Extract location
                if [idx for (idx, token) in enumerate(tokens) if token=='twiff']:
                    tokens = tokens[:[idx for (idx, token) in enumerate(tokens) if token=='twiff'][0]]
                location = ', '.join(tokens)                 
                
                could_parse = True
                
            except ValueError as e:
                None 
                
    end_time = time.time()
    times.append(end_time-start_time)
    print('Parsing tweet took: {:.3f} seconds'.format(end_time-start_time))      
    
    if could_parse:
        print(color.GREEN + 'Successfully parsed tweet.' + color.END)
        print(f'Number of People: {num_people}\nOrganization: {organization}\nLocation: {location}\nDatetime: {date}\n')
    else:
        print(color.RED + 'Unable to parse: {}...'.format(tweet.text[:100]) + color.END)
        print('Tokenized Text: {}\n\n'.format(tokens))
    
    
    
print('Was able to parse {}/{} tweets, {} tweets were not able to be parsed.'.format(valid_count, len(results.tweets.values()), len(results.tweets.values())-valid_count))
print('Average Time to Parse: {:.3f} seconds'.format(sum(times)/len(results.tweets.values())))
# Out:
# 0
# 1479474025596260355 @ 2022-01-07T15:24:29.000Z by Nasadox
# Parsing tweet took: 0.003 seconds
# Unable to parse: #ClimateStrike Week20
# This Year We must Ensure to do Best for Our Only Planet ❕
# More Sustainability🌎...
# Tokenized Text: ['climatestrike', 'week20', 'this', 'year', 'we', 'must', 'ensure', 'to', 'do', 'best', 'for', 'our', 'only', 'planet', 'more', 'sustainability', 'more', 'recycling', 'more', 'plantation', 'eco-transportation', 'saving', 'water', 'no', 'single-use', 'plastic', 'net', 'zero', 'actions', 'fridaysforfuture', 'twiff', 'climateactionnow', 'recycle_ow']
#
#
# 1
# 1479422653572255745 @ 2022-01-07T12:00:21.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 1.033 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: germany, hamburg
# Datetime: 2022-01-07 12:00:21
#
# 2
# 1479383912484900866 @ 2022-01-07T09:26:25.000Z by Barbara Fischer
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 6
# Organization: germany
# Location: berlin, join, our, vigil, from, 10, to, 12, to, makeparisreal
# Datetime: 2022-01-07 00:00:00
#
# 3
# 1479373300019208196 @ 2022-01-07T08:44:14.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.025 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: africa, lake, chad
# Datetime: 2022-01-07 08:44:14
#
# 4
# 1479370775543091201 @ 2022-01-07T08:34:12.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.013 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: itay
# Datetime: 2022-01-07 08:34:12
#
# 5
# 1479370161606078466 @ 2022-01-07T08:31:46.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.015 seconds
# Successfully parsed tweet.
# Number of People: 7
# Organization: fridaysforfuture
# Location: uk
# Datetime: 2022-01-06 00:00:00
#
# 6
# 1479368870511136772 @ 2022-01-07T08:26:38.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.019 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: uk, telford
# Datetime: 2022-01-07 08:26:38
#
# 7
# 1479367839203139587 @ 2022-01-07T08:22:32.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.025 seconds
# Successfully parsed tweet.
# Number of People: 7
# Organization: fridaysforfuture
# Location: india, new, delhi
# Datetime: 2022-01-07 08:22:32
#
# 8
# 1479358880165552128 @ 2022-01-07T07:46:56.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: sweden, svedmyra
# Datetime: 2022-01-07 00:00:00
#
# 9
# 1478692134974902273 @ 2022-01-05T11:37:32.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.021 seconds
# Successfully parsed tweet.
# Number of People: 30
# Organization: fridaysforfuture
# Location: uganda, kampala
# Datetime: 2021-01-04 00:00:00
#
# 10
# 1477214484754276353 @ 2022-01-01T09:45:53.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: netherlands
# Datetime: 2021-12-31 00:00:00
#
# 11
# 1476967914930679809 @ 2021-12-31T17:26:06.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.014 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: sweden
# Datetime: 2021-12-31 17:26:06
#
# 12
# 1476948328139169808 @ 2021-12-31T16:08:16.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.001 seconds
# Unable to parse: @fischerdata @FFFMapCount @bella_linne @endelstamberg @AaravSeth_ @TomsTweeters @redmayne_robert @ma...
# Tokenized Text: ['fischerdata', 'fffmapcount', 'bella_linne', 'endelstamberg', 'aaravseth_', 'tomstweeters', 'redmayne_robert', 'madlove_love', 'isstratkotter', 'gryllsmaitreya', 'climateyamin', 'lots', 'of', 'great', 'bots', 'coming', 'out', 'thank', 'you', 'theswedishbot', 'michalspano', 'fffbot1', 'amity_ak97', 'please', 'join', 'us', 'with', 'the', 'twiff', 'twiff_bot', 'all', 'ideas', 'are', 'welcome', 'the', 'fffmapcount', 'team', 'uses', 'this', 'vision', 'proposal', 'to', 'join', 'the', 'team', 'fffmapcount']
#
#
# 13
# 1476945512809050114 @ 2021-12-31T15:57:05.000Z by 💧 Janine Climate #UprootTheSystem
# C:\Users\samca\anaconda3\envs\twiff\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: uganda, tororo
# Datetime: 2021-12-31 00:00:00
#
# 14
# 1476943674068111399 @ 2021-12-31T15:49:46.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: sweden, svedmyra
# Datetime: 2021-12-31 00:00:00
#
# 15
# 1476872063654768641 @ 2021-12-31T11:05:13.000Z by Tom #FFFMapCount💚🌍🌎🌏💚
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: philippines
# Datetime: 2021-12-31 00:00:00
#
# 16
# 1476868574216011776 @ 2021-12-31T10:51:21.000Z by Nasadox
# Parsing tweet took: 0.000 seconds
# Unable to parse: #ClimateStrike Week19
# Another Year passed but
# What we got!!**
# What we Lost ?
# 🌳🌎♻
# #FridaysForFutur...
# Tokenized Text: ['climatestrike', 'week19', 'another', 'year', 'passed', 'but', 'what', 'we', 'got', 'what', 'we', 'lost', 'fridaysforfuture', 'uprootthesystem', 'climatecrisis', 'climateaction', 'climatejustice', 'twiff', 'recycle_ow', 'cccaazambia', 'fff_whk', 'fffpunjab', 'fffmapcount', 'xrrebeleveryday', 'extinctionr_de']
#
#
# 17
# 1476864235862958111 @ 2021-12-31T10:34:07.000Z by Barbara Fischer
# Parsing tweet took: 0.000 seconds
# Unable to parse: #FridaysForFuture finally some more people join us. Here some girls from Aachen to #MakeParisReal #T...
# Tokenized Text: ['fridaysforfuture', 'finally', 'some', 'more', 'people', 'join', 'us', 'here', 'some', 'girls', 'from', 'aachen', 'to', 'makeparisreal', 'twiff', 'climateaction']
#
#
# 18
# 1476851470318379026 @ 2021-12-31T09:43:23.000Z by Barbara Fischer
# Parsing tweet took: 0.000 seconds
# Unable to parse: The last day of the year is not the last #FridaysForFuture  We are here @Bundestag as long as it tak...
# Tokenized Text: ['the', 'last', 'day', 'of', 'the', 'year', 'is', 'not', 'the', 'last', 'fridaysforfuture', 'we', 'are', 'here', 'bundestag', 'as', 'long', 'as', 'it', 'takes', 'to', 'makeparisreal', 'twiff']
#
#
# 19
# 1476833103880597504 @ 2021-12-31T08:30:24.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Parsing tweet took: 0.587 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: f4fao
# Location: cassequel, 31, 12, 2021
# Datetime: 2021-12-31 08:30:24
#
# 20
# 1476830531660754944 @ 2021-12-31T08:20:11.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Parsing tweet took: 0.204 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: f4fao
# Location: cassequel, 31, 12, 2021
# Datetime: 2021-12-31 08:20:11
#
# 21
# 1476702297862377476 @ 2021-12-30T23:50:38.000Z by Barbara Fischer
# Parsing tweet took: 0.000 seconds
# Unable to parse: #DontLookUp Es ist wieder Freitag. Von 10 bis 12 Mahnwache für das #ParisAgreement vor dem Bundestag...
# Tokenized Text: ['dontlookup', 'es', 'ist', 'wieder', 'freitag', 'von', '10', 'bis', '12', 'mahnwache', 'für', 'das', 'parisagreement', 'vor', 'dem', 'bundestag', 'wie', 'immer', 'fridaysforfuture', 'twiff', 'climateaction', 'wenn', 'die', 'politik', 'doch', 'endlich', 'loslegte', 'das', 'ist', 'mein', 'hoffnungsträumen', 'für', '2022', 'schaut', 'den', 'film', 'er', 'bringt', 'es', 'auf', 'den', 'punkt']
#
#
# 22
# 1476294800123076609 @ 2021-12-29T20:51:23.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.000 seconds
# Unable to parse: #twiff, test...
# Tokenized Text: ['twiff', 'tes']
#
#
# 23
# 1475936120265445377 @ 2021-12-28T21:06:07.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: usa
# Datetime: 2021-11-09 00:00:00
#
# 24
# 1475789543785877508 @ 2021-12-28T11:23:40.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.021 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: sweden, svedmyra
# Datetime: 2021-12-24 00:00:00
#
# 25
# 1474351985981804549 @ 2021-12-24T12:11:20.000Z by Barbara Fischer
# Parsing tweet took: 0.020 seconds
# Successfully parsed tweet.
# Number of People: 5
# Organization: people
# Location: in, berlin
# Datetime: 2021-12-24 12:11:20
#
# 26
# 1474351793379454979 @ 2021-12-24T12:10:34.000Z by Barbara Fischer
# Parsing tweet took: 0.019 seconds
# Successfully parsed tweet.
# Number of People: 3
# Organization: people
# Location: in, berlin
# Datetime: 2021-12-24 12:10:34
#
# 27
# 1474351677675348000 @ 2021-12-24T12:10:06.000Z by Barbara Fischer
# Parsing tweet took: 0.019 seconds
# Successfully parsed tweet.
# Number of People: 5
# Organization: people
# Location: in, berlin
# Datetime: 2021-12-24 12:10:06
#
# 28
# 1474313058134761475 @ 2021-12-24T09:36:39.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Parsing tweet took: 0.196 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: f4fao
# Location: maianga, 24, 12, 2021
# Datetime: 2021-12-24 09:36:39
#
# 29
# 1473576395166998532 @ 2021-12-22T08:49:24.000Z by @Twiff_bot 🌏 #Twiff
# This tweet way made by @Twiff_bot 🌏 #Twiff not by an external user!
# Parsing tweet took: 0.000 seconds
# Unable to parse: @JanineClimate @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubara...
# Tokenized Text: ['janineclimate', 'aaravseth_', 'redmayne_robert', 'climatebabes', 'climatepowers', 'amirtha5116', 'fazeelamubarak', 'winniecheche', 'martelocris', 'imandiu', 'emaanzt', 'madlove_love', 'tomstweeters', 'chanchaljangir9', 'kabilaobbo', 'denisnishant', 'andrew88820142', 'krosenlund_com', 'vikashbalmuchu', 'endelstamberg', 'geraldkutney', 'wakiodorcas', 'thanks', 'janineclimate', 'for', 'your', 'climate', 'action', 'and', 'using', 'twiff', 'i', 'wasn', 't', 'able', 'to', 'extract', 'any', 'fields', 'from', 'your', 'tweet', 'to', 'have', 'your', 'action', 'registered', 'please', 'reply', 'using', 'the', 'following', 'format', 'twiff', 'number', 'of', 'people', 'organization', 'location', 'datetime']
#
#
# 30
# 1473576069512921093 @ 2021-12-22T08:48:07.000Z by @Twiff_bot 🌏 #Twiff
# This tweet way made by @Twiff_bot 🌏 #Twiff not by an external user!
# Parsing tweet took: 0.000 seconds
# Unable to parse: @JanineClimate @act_nowclimate @nzlabour @NZNationalParty @GretaThunberg @FFFMapCount @TomsTweeters ...
# Tokenized Text: ['janineclimate', 'act_nowclimate', 'nzlabour', 'nznationalparty', 'gretathunberg', 'fffmapcount', 'tomstweeters', 'thanks', 'janineclimate', 'for', 'your', 'climate', 'action', 'and', 'using', 'twiff', 'people', '2', 'org', 'climateaction', 'location', 'nz', 'goughs', 'bay', 'date', '2021-12-20', 'if', 'any', 'fields', 'are', 'incorrect', 'please', 'reply', 'using', 'the', 'following', 'format', 'twiff', 'number', 'of', 'people', 'organization', 'location', 'datetime']
#
#
# 31
# 1473006074148147202 @ 2021-12-20T19:03:09.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: climateaction
# Location: nz, goughs, bay
# Datetime: 2021-12-20 00:00:00
#
# 32
# 1472884160268283907 @ 2021-12-20T10:58:43.000Z by Fridays For Future AO #UprootTheSystem
# Parsing tweet took: 0.030 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: angola, luanda, maianga
# Datetime: 2021-12-17 00:00:00
#
# 33
# 1472883409978593280 @ 2021-12-20T10:55:44.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Parsing tweet took: 0.030 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fridaysforfuture
# Location: angola, maianga, luanda
# Datetime: 2021-12-01 00:00:00
#
# 34
# 1472315758680100864 @ 2021-12-18T21:20:05.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.031 seconds
# Successfully parsed tweet.
# Number of People: 6
# Organization: saturdaysforfuture
# Location: sweden, stockholm, medborgarplasten
# Datetime: 2021-12-18 00:00:00
#
# 35
# 1472148726798077952 @ 2021-12-18T10:16:22.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 13
# Organization: fffmapcount
# Location: nederland, limburg, roermond
# Datetime: 2021-12-18 00:00:00
#
# 36
# 1472145220997373952 @ 2021-12-18T10:02:26.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 35
# Organization: fffmapcount
# Location: uganda
# Datetime: 2021-12-18 00:00:00
#
# 37
# 1472144756063064066 @ 2021-12-18T10:00:35.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fffmapcount
# Location: uganda, kampala
# Datetime: 2021-12-18 00:00:00
#
# 38
# 1472144257419030530 @ 2021-12-18T09:58:36.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.020 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: eestis
# Datetime: 2021-12-18 00:00:00
#
# 39
# 1472143800512438282 @ 2021-12-18T09:56:47.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: poland
# Datetime: 2021-12-18 00:00:00
#
# 40
# 1471971600027336708 @ 2021-12-17T22:32:32.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 7
# Organization: fridaysforfuture
# Location: germany, berlin, url
# Datetime: 2021-12-17 00:00:00
#
# 41
# 1471971031560691727 @ 2021-12-17T22:30:16.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 5
# Organization: fridaysforfuture
# Location: sweden, kungsholmen
# Datetime: 2021-12-17 00:00:00
#
# 42
# 1471968708285415428 @ 2021-12-17T22:21:02.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 7
# Organization: fridaysforfuture
# Location: germany, berlin
# Datetime: 2021-12-17 00:00:00
#
# 43
# 1471950743167021066 @ 2021-12-17T21:09:39.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.001 seconds
# Unable to parse: @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubarak @WinnieCheche...
# Tokenized Text: ['aaravseth_', 'redmayne_robert', 'climatebabes', 'climatepowers', 'amirtha5116', 'fazeelamubarak', 'winniecheche', 'martelocris', 'imandiu', 'emaanzt', 'madlove_love', 'tomstweeters', 'chanchaljangir9', 'kabilaobbo', 'denisnishant', 'andrew88820142', 'krosenlund_com', 'vikashbalmuchu', 'endelstamberg', 'geraldkutney', 'wakiodorcas', 'as', 'we', 'work', 'together', 'our', 'voices', 'gain', 'momentum', 'and', 'we', 'are', 'unstoppable', 'solidarity', 'climatestrike', 'fridaysforfuture', 'twiff']
#
#
# 44
# 1471950074053906439 @ 2021-12-17T21:06:59.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @ImandiU @tonytheauthor @KambojAnanya @BeeAsMarine @KaoHua3 @AaravSeth_ @ZillionTree @human @BhupalP...
# Tokenized Text: ['imandiu', 'tonytheauthor', 'kambojananya', 'beeasmarine', 'kaohua3', 'aaravseth_', 'zilliontree', 'human', 'bhupalpsr', 'almuthsiegl', 'tonyhussein4', 'vinnisha8848', 'endelstamberg', 'unocha', 'sdg13un', 'unesco', 'thank', 'you', 'solidarity', 'climatestrike', 'fridaysforfuture', 'twiff']
#
#
# 45
# 1471949423521714176 @ 2021-12-17T21:04:24.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @AaravSeth_ @arifismail0 @mnyomb1 @Anushka_nature @IvyKriss @WakioDorcas @mrEmTee @Thakrarkhelan @De...
# Tokenized Text: ['aaravseth_', 'arifismail0', 'mnyomb1', 'anushka_nature', 'ivykriss', 'wakiodorcas', 'mremtee', 'thakrarkhelan', 'denisnishant', 'torstenluetten', 'vikashbalmuchu', 'thekopargaonkar', 'jovanmaria123', 'riseupmovt', 'kaynair', 'josephusludwig', 'ramprakashmina', 'lifelearner47', 'gautamluhar2', 'this', 'is', 'the', 'work', 'of', 'angels', 'solidarity', 'climatestrike', 'fridaysforfuture', 'twiff']
#
#
# 46
# 1471948902865772559 @ 2021-12-17T21:02:20.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @endelstamberg @nataliebookout @moreau_doc @essennique @LeoOni1 @anastasiaserg2 @asyafomina_ru @LubY...
# Tokenized Text: ['endelstamberg', 'nataliebookout', 'moreau_doc', 'essennique', 'leooni1', 'anastasiaserg2', 'asyafomina_ru', 'lubyo', 'makichyana', 'weeanarchist', 'emma_ymp', 'lilliasworld', 'raiganl314', 'ronaldonyang1', 'mnyomb1', 'manukabila0', 'edwinnamakanga', 'denisnishant', 'superestribillo', 'excellent', 'thank', 'you', 'solidarity', 'climatestrike', 'fridaysforfuture', 'twiff']
#
#
# 47
# 1471939938757353481 @ 2021-12-17T20:26:43.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.024 seconds
# Successfully parsed tweet.
# Number of People: 7
# Organization: fridaysforfuture
# Location: sweden, svedmyra
# Datetime: 2021-12-17 00:00:00
#
# 48
# 1471925765642063881 @ 2021-12-17T19:30:24.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 19
# Organization: fridaysforfuture
# Location: finland, helsinki
# Datetime: 2021-12-17 00:00:00
#
# 49
# 1471924280044703757 @ 2021-12-17T19:24:30.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 3
# Organization: forests
# Location: india, auroville
# Datetime: 2021-12-17 00:00:00
#
# 50
# 1471923428072509450 @ 2021-12-17T19:21:06.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 4
# Organization: fridaysforfuture
# Location: india, punjab
# Datetime: 2021-12-17 00:00:00
#
# 51
# 1471922072213499917 @ 2021-12-17T19:15:43.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 4
# Organization: fridaysforfuture
# Location: india, dehli
# Datetime: 2021-12-17 00:00:00
#
# 52
# 1471921382233714697 @ 2021-12-17T19:12:59.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.023 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: climatestrike
# Location: poland, lancut
# Datetime: 2021-12-17 00:00:00
#
# 53
# 1470821530414243840 @ 2021-12-14T18:22:34.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 10
# Organization: lastgeneration
# Location: germany
# Datetime: 2021-12-14 00:00:00
#
# 54
# 1470370904148488196 @ 2021-12-13T12:31:56.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: angola, cassequel, luanda
# Datetime: 2021-10-15 00:00:00
#
# 55
# 1470362662198554626 @ 2021-12-13T11:59:11.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fridaysforfuture
# Location: country, region, town
# Datetime: 2021-10-15 00:00:00
#
# 56
# 1470200239760068613 @ 2021-12-13T01:13:46.000Z by Mario Lanza
# Parsing tweet took: 0.000 seconds
# Unable to parse: #twiff 🙃🙃🙃 ♥️ https://t.co/oxAMuGRrIV...
# Tokenized Text: ['twiff']
#
#
# 57
# 1469956781208223746 @ 2021-12-12T09:06:21.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 6
# Organization: fridaysforfuture
# Location: new, zealand, wellington
# Datetime: 2021-12-12 09:06:21
#
# 58
# 1468572384340983813 @ 2021-12-08T13:25:15.000Z by @Twiff_bot 🌏 #Twiff
# This tweet way made by @Twiff_bot 🌏 #Twiff not by an external user!
# Parsing tweet took: 0.029 seconds
# Successfully parsed tweet.
# Number of People: 16
# Organization: fffmapcount
# Location: netherlands, noord-brabant, breda
# Datetime: 2021-12-08 13:25:15
#
# 59
# 1467878798150488066 @ 2021-12-06T15:29:12.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: germany, berlin
# Datetime: 2021-12-06 15:29:12
#
# 60
# 1467827378642694147 @ 2021-12-06T12:04:52.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fffmapcount
# Location: usa, cambridge
# Datetime: 2022-01-11 20:23:47.783467
#
# 61
# 1467825346791759872 @ 2021-12-06T11:56:48.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.021 seconds
# Successfully parsed tweet.
# Number of People: 2
# Organization: fffmapcount
# Location: france, toulouse
# Datetime: 2021-12-06 11:56:48
#
# 62
# 1467818568754634758 @ 2021-12-06T11:29:52.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.022 seconds
# Successfully parsed tweet.
# Number of People: 13
# Organization: saturdaysforfuture
# Location: sweden, medborgarplatsen
# Datetime: 2021-12-04 00:00:00
#
# 63
# 1467814415185727493 @ 2021-12-06T11:13:21.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.144 seconds
# Successfully parsed tweet.
# Number of People: 4
# Organization: fffmapcount
# Location: india, delhi
# Datetime: 2021-12-06 11:13:21
#
# 64
# 1467813536349003776 @ 2021-12-06T11:09:52.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.020 seconds
# Successfully parsed tweet.
# Number of People: 4
# Organization: fffmapcount
# Location: india, delhi
# Datetime: 2021-12-06 11:09:52
#
# 65
# 1467811401586642946 @ 2021-12-06T11:01:23.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: germany
# Datetime: 2021-12-05 00:00:00
#
# 66
# 1467810539652980741 @ 2021-12-06T10:57:57.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.021 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: germany, hamburg
# Datetime: 2021-12-03 00:00:00
#
# 67
# 1467809152600789028 @ 2021-12-06T10:52:27.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.028 seconds
# Successfully parsed tweet.
# Number of People: 6
# Organization: fffmapcount
# Location: sweden, gustavsberg, date
# Datetime: 2021-12-03 00:00:00
#
# 68
# 1467807940262477825 @ 2021-12-06T10:47:38.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.016 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: usa, cambridge
# Datetime: 2022-01-11 20:23:48.071968
#
# 69
# 1467806531311788040 @ 2021-12-06T10:42:02.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.020 seconds
# Successfully parsed tweet.
# Number of People: 10
# Organization: fffmapcount
# Location: sweden, vännäs
# Datetime: 2021-12-06 10:42:02
#
# 70
# 1467578842399313926 @ 2021-12-05T19:37:16.000Z by 11thHFC
# Parsing tweet took: 0.001 seconds
# Unable to parse: #twiff Ewhurst, Cranleigh, UK: 2021-12-02, 2 striking for #11thHourForClimate with #FridaysForFuture...
# Tokenized Text: ['twiff', 'ewhurst', 'cranleigh', 'uk', '2021-12-02', '2', 'striking', 'for', '11thhourforclimate', 'with', 'fridaysforfutur']
#
#
# 71
# 1467450340341653508 @ 2021-12-05T11:06:39.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.000 seconds
# Unable to parse: #twiff
# Date:2021-12-03
# People:25
# Org:FFFMapCount
# Country:Bangladesh
# Town:Dhaka
# URL:https://t.co/41x6...
# Tokenized Text: ['twiff', 'date', '2021-12-03', 'people', '25', 'org', 'fffmapcount', 'country', 'bangladesh', 'town', 'dhaka', 'url']
#
#
# 72
# 1467448015384371200 @ 2021-12-05T10:57:25.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.021 seconds
# Successfully parsed tweet.
# Number of People: 400
# Organization: fffmapcount
# Location: deutschland, aachen
# Datetime: 2021-12-05 10:57:25
#
# 73
# 1467446392125861890 @ 2021-12-05T10:50:58.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.020 seconds
# Successfully parsed tweet.
# Number of People: 1
# Organization: fffmapcount
# Location: india, mohali
# Datetime: 2021-12-05 10:50:58
#
# 74
# 1466894039224045578 @ 2021-12-03T22:16:07.000Z by @FFF_SAJ ._. Sweden Årsta Janine #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @Vikrant_sri29 @redmayne_robert @narendramodi @BBCWorld @UN @UNYouthEnvoy @UNEP @byadavbjp @COP26 @M...
# Tokenized Text: ['vikrant_sri29', 'redmayne_robert', 'narendramodi', 'bbcworld', 'un', 'unyouthenvoy', 'unep', 'byadavbjp', 'cop26', 'mockcop26', 'great', 'work', 'thank', 'you', 'this', 'is', 'a', 'twiff']
#
#
# 75
# 1466888367480651788 @ 2021-12-03T21:53:34.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @DawnRoseTurner @NayonSorkarBD @GretaThunberg @SwedenAmbBD @SaveFutureBd @Fridays4future @UNEP_Europ...
# Tokenized Text: ['dawnroseturner', 'nayonsorkarbd', 'gretathunberg', 'swedenambbd', 'savefuturebd', 'fridays4future', 'unep_europe', 'unbiodiversity', 'wwf', 'saberhc', 'swissambbd', 'unicefbd', 'tomstweeters', 'is', 'climateemergency', 'born', 'of', 'the', 'rich', 'by', 'the', 'rich', 'for', 'the', 'rich', 'thank', 'you', 'for', 'your', 'work', 'fridaysforfuture', 'twiff', 'standing', 'with', 'you', 'in', 'every', 'word']
#
#
# 76
# 1466887738452496384 @ 2021-12-03T21:51:04.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @ShikhaSeth17 @GretaThunberg @vanessa_vash @KaoHua3 @Fridays4future @FFFIndia @FFFMAPA @parents4futu...
# Tokenized Text: ['shikhaseth17', 'gretathunberg', 'vanessa_vash', 'kaohua3', 'fridays4future', 'fffindia', 'fffmapa', 'parents4future', 'rwclimate', 'wakiodorcas', 'charlotteauman1', 'endelstamberg', 'extinctionr', 'redmayne_robert', 'tomstweeters', 'eriksolheim', 'geraldkutney', 'is', 'our', 'climateemergency', 'a', 'form', 'of', 'legal', 'hate', 'to', 'us', 'our', 'future', 'and', 'all', 'of', 'nature', 'is', 'it', 'born', 'of', 'the', 'rich', 'by', 'the', 'rich', 'for', 'the', 'rich', 'thank', 'you', 'for', 'your', 'work', 'fridaysforfuture', 'twiff', 'standing', 'with', 'you', 'in', 'every', 'word']
#
#
# 77
# 1466885984994349057 @ 2021-12-03T21:44:06.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @FFF_SAJ @FFFMapCount @Leyse65081133 @endelstamberg @Steffenster @fischerdata @stefangsaenger @WeNat...
# Tokenized Text: ['fff_saj', 'fffmapcount', 'leyse65081133', 'endelstamberg', 'steffenster', 'fischerdata', 'stefangsaenger', 'wenaturalists', 'nayonsorkarbd', 'twongirwe_ireen', 'ygcuganda', 'tomstweeters', 'thiesabine', 'wwindea', 'wiligl', 'extinctionr_sv', 'thakrarkhelan', 'redmayne_robert', 'vipinsangwanvs', 'arifismail0', 'voicetopeople', 'yamunajiye', 'rwclimate', 'shreyatuli_', 'ivykriss', 'wakiodorcas', 'mremtee', 'thekopargaonkar', 'denisnishant', 'arunyadav0007', 'sachinjacobk', 'parents4future', 'jovanmaria123', 'madlove_love', 'fridays_india', 'releaf4us', 'swedishpm', 'fff_sssat', 'adamsrigley', 'arhogan', 'arubafaruque', 'mrs_dalloway_', 'fff_tui', 'annatermine2', 'bespokepanic', 'bella_linne', 'shell', 'wwf', 'afiegoug', 'dec', '3', 'week', '172', 'gustavsberg', 'stockholm', 'amazon', 's', 'shell', 's', 'amp', 'more', 'greed', 'creates', 'climatebreakdown', 'poverty', 'inequality', 'how', 'many', 'deaths', 'is', 'climateemergency', 'creating', 'now', 'politicians', 'say', '2050', 'blahblahblah', 'fridaysforfuture', 'climatestrike', 'uprootthesystem', 'twiff']
#
#
# 78
# 1466437155765563412 @ 2021-12-02T16:00:37.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @RMBlaber5...
# Tokenized Text: ['sdg13un', 'ibraheemlass', 'ptrebaul', 'inbusiness4good', 'tomstweeters', 'fff_aus', 'kaohua3', 'solhog', 'rmblaber56', 'fromjimbarnes', 'fffmapcount', 'thakrarkhelan', 'marinegofficial', 'dawnroseturner', 'fff_jour', 'vinnisha8848', 'endelstamberg', 'fff_saj', 'kathleenmartsch', 'jojoju15', 'arty_gital', 'monopolsiedler', 'luckmann2008', 'xr_aufstand', 'fischerdata', 'alexand99589931', 'voicetopeople', 'arifismail0', 'redmayne_robert', 'jnwamson', 'ros_rodriguez_', 'shantaw_nur', 'anthonygleeson4', 'denisnishant', 'resistance411', 'ecowarriorss', 'panachevert', 'mrs_dalloway_', 'arubafaruque', 'howey_ou', 'buckethatalice', 'j_olwenyi', '_carbontiptoes', 'rise4climate', 'leo_jiboiana', 'espiritomundo', 'saskiabricmont', 'actionon_amazon', 'progintl', 'this', 'needs', 'counting', 'lillyspickup', 'has', 'been', 'regularly', 'striking', 'for', 'a', 'long', 'long', 'time', 'fffmapcount', 'fridaysforfuture', 'twiff', 'climatestrike']
#
#
# 79
# 1466118638562426881 @ 2021-12-01T18:54:57.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @SDO_Org Thanks for your #ClimateAction &amp; using #Twiff
# No pre reg found
# Date:2021-11-29
# People:1...
# Tokenized Text: ['sdo_org', 'thanks', 'for', 'your', 'climateaction', 'amp', 'using', 'twiff', 'no', 'pre', 'reg', 'found', 'date', '2021-11-29', 'people', '1', 'org', 'fffmapcount', 'country', 'pakistan', 'state', 'town', 'islamabad', 'url']
#
#
# 80
# 1466117777136050177 @ 2021-12-01T18:51:31.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Parsing tweet took: 0.026 seconds
# Successfully parsed tweet.
# Number of People: 4
# Organization: fffmapcount
# Location: svedmyra, stockholm, sweden
# Datetime: 2021-12-01 18:51:31
#
# 81
# 1466075160843276298 @ 2021-12-01T16:02:11.000Z by 💧 Janine Climate #UprootTheSystem
# Parsing tweet took: 0.000 seconds
# Unable to parse: @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @RMBlaber56 @Sdg13U...
# Tokenized Text: ['ibraheemlass', 'ptrebaul', 'inbusiness4good', 'tomstweeters', 'fff_aus', 'kaohua3', 'solhog', 'rmblaber56', 'sdg13un', 'fromjimbarnes', 'fffmapcount', 'thakrarkhelan', 'marinegofficial', 'dawnroseturner', 'fff_jour', 'vinnisha8848', 'endelstamberg', 'fff_saj', 'kathleenmartsch', 'jojoju15', 'arty_gital', 'monopolsiedler', 'luckmann2008', 'xr_aufstand', 'fischerdata', 'alexand99589931', 'voicetopeople', 'arifismail0', 'redmayne_robert', 'jnwamson', 'ros_rodriguez_', 'shantaw_nur', 'anthonygleeson4', 'denisnishant', 'resistance411', 'ecowarriorss', 'panachevert', 'mrs_dalloway_', 'arubafaruque', 'howey_ou', 'buckethatalice', 'j_olwenyi', '_carbontiptoes', 'rise4climate', 'leo_jiboiana', 'espiritomundo', 'saskiabricmont', 'actionon_amazon', 'progintl', 'thanks', 'for', 'your', 'climateaction', 'amp', 'using', 'twiff', 'no', 'pre', 'reg', 'found', 'date', '2021-12-01', 'people', '1', 'org', 'fffmapcount', 'country', 'india', 'state', 'town', 'url']
#
#
# Was able to parse 59/82 tweets, 23 tweets were not able to be parsed.
# Average Time to Parse: 0.041 seconds

# %%
# 73%
# 0.018s

# %%
set(organization_list)
# Out:
# {'climateaction',
#  'climatestrike',
#  'f4fao',
#  'fffmapcount',
#  'forests',
#  'fridaysforfuture',
#  'germany',
#  'lastgeneration',
#  'people',
#  'saturdaysforfuture'}

# %% [markdown]
# ## Relaxed Parsing

# %%
import re
import datetime
import torchtext
import dateparser

times = []

valid_count = 0

relaxed_parse = False
attempt_clean_url_entities = True

for idx, (key, tweet) in enumerate(list(results.tweets.items())[::-1]):
    start_time = time.time()
    could_parse = False
    
    print(idx)
    print(color.BOLD + '{} @ {} by {}' .format(tweet.id, tweet.created_at, results.users[tweet.author_id].name) + color.END)
    
    # Clean up entities
    url_start_idx = tweet.entities['urls'][0]['start'] if 'urls' in tweet.entities and attempt_clean_url_entities else -1
    
    # Clean text
    text = tweet.text[:url_start_idx].strip().lower()
    text = remove_emoji(text)
    text = re.sub('[,:;(){}##/?@!.\[\]&%$*^\+=|<>`~"\']', ' ', text)
    text = re.sub('  ', ' ', text)
    
    # Tokenize the text (could also split but less reliable)
    tokens = torchtext.data.get_tokenizer("basic_english")(text)    
    
    if not relaxed_parse:
        relaxed_num_people = None
        relaxed_organization = []
        relaxed_location = None
        relaxed_datetime = None
        for token in tokens:
            # Try parse token as a number?
            if not relaxed_num_people:
                try:
                    int(token)
                    relaxed_num_people = int(token)
                except ValueError as e:
                    None
                
            if not relaxed_datetime:
                # Try parse token as a datetime?
                relaxed_datetime = dateparser.parse(token, settings={'STRICT_PARSING':True})
            
            if token in set(organization_list):
                relaxed_organization.append(token)

    na_str = color.RED + 'N/A' + color.END
    could_parse = (relaxed_num_people is not None) and (relaxed_organization is not None)
    num_people = na_str if not relaxed_num_people else color.GREEN + '{}'.format(relaxed_num_people) + color.END
    organization = na_str if not relaxed_organization else color.GREEN + '/'.join(list(set(relaxed_organization))) + color.END
    location = color.RED + na_str + color.END
    datetime = color.YELLOW + '{}'.format(tweet.created_at) + color.END if not relaxed_datetime else color.GREEN + '{}'.format(relaxed_datetime) + color.END
    
    end_time = time.time()
    
    
    if could_parse:
        print(f'Number of People: {num_people}\nOrganization: {organization}\nLocation: {location}\nDatetime: {datetime}\n')
        valid_count += 1
    else:
        print(color.RED + 'Unable to parse: {}...\n'.format(tweet.text[:100]) + color.END)
    
print('Was able to parse {}/{} tweets, {} tweets were not able to be parsed.'.format(valid_count, len(results.tweets.values()), len(results.tweets.values())-valid_count))
print('Average Time to Parse: {:.3f} seconds'.format(sum(times)/len(results.tweets.values())))
# Out:
# 0
# 1477214484754276353 @ 2022-01-01T09:45:53.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-31 00:00:00
#
# 1
# 1476967914930679809 @ 2021-12-31T17:26:06.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-31T17:26:06.000Z
#
# 2
# 1476948328139169808 @ 2021-12-31T16:08:16.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @fischerdata @FFFMapCount @bella_linne @endelstamberg @AaravSeth_ @TomsTweeters @redmayne_robert @ma...
#
# 3
# 1476945512809050114 @ 2021-12-31T15:57:05.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-31 00:00:00
#
# 4
# 1476943674068111399 @ 2021-12-31T15:49:46.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2021
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-31 00:00:00
#
# 5
# 1476872063654768641 @ 2021-12-31T11:05:13.000Z by Tom #FFFMapCount💚🌍🌎🌏💚
# Number of People: 1
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-31 00:00:00
#
# 6
# 1476868574216011776 @ 2021-12-31T10:51:21.000Z by Nasadox
# Unable to parse: #ClimateStrike Week19
# Another Year passed but
# What we got!!**
# What we Lost ?
# 🌳🌎♻
# #FridaysForFutur...
#
# 7
# 1476864235862958111 @ 2021-12-31T10:34:07.000Z by Barbara Fischer
# Unable to parse: #FridaysForFuture finally some more people join us. Here some girls from Aachen to #MakeParisReal #T...
#
# 8
# 1476851470318379026 @ 2021-12-31T09:43:23.000Z by Barbara Fischer
# Unable to parse: The last day of the year is not the last #FridaysForFuture  We are here @Bundestag as long as it tak...
#
# 9
# 1476833103880597504 @ 2021-12-31T08:30:24.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Number of People: 29
# Organization: f4fao/fridaysforfuture/climatestrike
# Location: N/A
# Datetime: 2022-01-03 18:48:19.624817
#
# 10
# 1476830531660754944 @ 2021-12-31T08:20:11.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Number of People: 29
# Organization: f4fao/fridaysforfuture/climatestrike
# Location: N/A
# Datetime: 2022-01-03 18:48:19.718318
#
# 11
# 1476702297862377476 @ 2021-12-30T23:50:38.000Z by Barbara Fischer
# Number of People: 10
# Organization: fridaysforfuture/climateaction
# Location: N/A
# Datetime: 2021-12-30T23:50:38.000Z
#
# 12
# 1476294800123076609 @ 2021-12-29T20:51:23.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Unable to parse: #twiff, test...
#
# 13
# 1475936120265445377 @ 2021-12-28T21:06:07.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-11-09 00:00:00
#
# 14
# 1475789543785877508 @ 2021-12-28T11:23:40.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 175
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-24 00:00:00
#
# 15
# 1474351985981804549 @ 2021-12-24T12:11:20.000Z by Barbara Fischer
# Number of People: 5
# Organization: people/climateaction
# Location: N/A
# Datetime: 2021-12-24T12:11:20.000Z
#
# 16
# 1474351793379454979 @ 2021-12-24T12:10:34.000Z by Barbara Fischer
# Number of People: 3
# Organization: people/climateaction
# Location: N/A
# Datetime: 2021-12-24T12:10:34.000Z
#
# 17
# 1474351677675348000 @ 2021-12-24T12:10:06.000Z by Barbara Fischer
# Number of People: 5
# Organization: people/climateaction
# Location: N/A
# Datetime: 2021-12-24T12:10:06.000Z
#
# 18
# 1474313058134761475 @ 2021-12-24T09:36:39.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Number of People: 28
# Organization: f4fao/fridaysforfuture/climatestrike
# Location: N/A
# Datetime: 2021-12-24T09:36:39.000Z
#
# 19
# 1473576395166998532 @ 2021-12-22T08:49:24.000Z by @Twiff_bot 🌏 #Twiff
# Unable to parse: @JanineClimate @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubara...
#
# 20
# 1473576069512921093 @ 2021-12-22T08:48:07.000Z by @Twiff_bot 🌏 #Twiff
# Number of People: 2
# Organization: people/fffmapcount/climateaction
# Location: N/A
# Datetime: 2021-12-20 00:00:00
#
# 21
# 1473006074148147202 @ 2021-12-20T19:03:09.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fffmapcount/climateaction
# Location: N/A
# Datetime: 2022-01-03 18:48:22.470817
#
# 22
# 1472884160268283907 @ 2021-12-20T10:58:43.000Z by Fridays For Future AO #UprootTheSystem
# Number of People: 1
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 23
# 1472883409978593280 @ 2021-12-20T10:55:44.000Z by Auber Fichess 🇯🇴#PalestinaLivre
# Number of People: 1
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-01 00:00:00
#
# 24
# 1472315758680100864 @ 2021-12-18T21:20:05.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 6
# Organization: saturdaysforfuture
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 25
# 1472148726798077952 @ 2021-12-18T10:16:22.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 13
# Organization: fffmapcount/people/climatestrike
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 26
# 1472145220997373952 @ 2021-12-18T10:02:26.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 35
# Organization: fffmapcount/people/climatestrike
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 27
# 1472144756063064066 @ 2021-12-18T10:00:35.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 2
# Organization: fffmapcount/people/climatestrike
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 28
# 1472144257419030530 @ 2021-12-18T09:58:36.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 1
# Organization: fffmapcount/people/climatestrike
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 29
# 1472143800512438282 @ 2021-12-18T09:56:47.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 1
# Organization: fffmapcount/people/climatestrike
# Location: N/A
# Datetime: 2021-12-18 00:00:00
#
# 30
# 1471971600027336708 @ 2021-12-17T22:32:32.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 7
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 31
# 1471971031560691727 @ 2021-12-17T22:30:16.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 174
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2022-01-03 18:48:25.740817
#
# 32
# 1471968708285415428 @ 2021-12-17T22:21:02.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 7
# Organization: fridaysforfuture/fffmapcount/climatestrike
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 33
# 1471950743167021066 @ 2021-12-17T21:09:39.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @AaravSeth_ @redmayne_robert @climatebabes @ClimatePowers @amirtha5116 @fazeelamubarak @WinnieCheche...
#
# 34
# 1471950074053906439 @ 2021-12-17T21:06:59.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @ImandiU @tonytheauthor @KambojAnanya @BeeAsMarine @KaoHua3 @AaravSeth_ @ZillionTree @human @BhupalP...
#
# 35
# 1471949423521714176 @ 2021-12-17T21:04:24.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @AaravSeth_ @arifismail0 @mnyomb1 @Anushka_nature @IvyKriss @WakioDorcas @mrEmTee @Thakrarkhelan @De...
#
# 36
# 1471948902865772559 @ 2021-12-17T21:02:20.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @endelstamberg @nataliebookout @moreau_doc @essennique @LeoOni1 @anastasiaserg2 @asyafomina_ru @LubY...
#
# 37
# 1471939938757353481 @ 2021-12-17T20:26:43.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 174
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 38
# 1471925765642063881 @ 2021-12-17T19:30:24.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 19
# Organization: fridaysforfuture/fffmapcount/climatestrike
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 39
# 1471924280044703757 @ 2021-12-17T19:24:30.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 3
# Organization: fffmapcount/forests
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 40
# 1471923428072509450 @ 2021-12-17T19:21:06.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 4
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 41
# 1471922072213499917 @ 2021-12-17T19:15:43.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 4
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 42
# 1471921382233714697 @ 2021-12-17T19:12:59.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: climatestrike
# Location: N/A
# Datetime: 2021-12-17 00:00:00
#
# 43
# 1470821530414243840 @ 2021-12-14T18:22:34.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 10
# Organization: lastgeneration
# Location: N/A
# Datetime: 2021-12-14 00:00:00
#
# 44
# 1470370904148488196 @ 2021-12-13T12:31:56.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fridaysforfuture/fffmapcount
# Location: N/A
# Datetime: 2021-10-15 00:00:00
#
# 45
# 1470362662198554626 @ 2021-12-13T11:59:11.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-10-15 00:00:00
#
# 46
# 1470200239760068613 @ 2021-12-13T01:13:46.000Z by Mario Lanza
# Unable to parse: #twiff 🙃🙃🙃 ♥️ https://t.co/oxAMuGRrIV...
#
# 47
# 1469956781208223746 @ 2021-12-12T09:06:21.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 6
# Organization: fridaysforfuture
# Location: N/A
# Datetime: 2021-12-12T09:06:21.000Z
#
# 48
# 1468572384340983813 @ 2021-12-08T13:25:15.000Z by @Twiff_bot 🌏 #Twiff
# Number of People: 16
# Organization: people/fffmapcount
# Location: N/A
# Datetime: 2021-12-08T13:25:15.000Z
#
# 49
# 1467878798150488066 @ 2021-12-06T15:29:12.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-06T15:29:12.000Z
#
# 50
# 1467827378642694147 @ 2021-12-06T12:04:52.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fffmapcount
# Location: N/A
# Datetime: 2022-01-03 18:48:30.510317
#
# 51
# 1467825346791759872 @ 2021-12-06T11:56:48.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 2
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-06T11:56:48.000Z
#
# 52
# 1467818568754634758 @ 2021-12-06T11:29:52.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 13
# Organization: fffmapcount/saturdaysforfuture
# Location: N/A
# Datetime: 2021-12-04 00:00:00
#
# 53
# 1467814415185727493 @ 2021-12-06T11:13:21.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 4
# Organization: people/fffmapcount
# Location: N/A
# Datetime: 2021-12-06T11:13:21.000Z
#
# 54
# 1467813536349003776 @ 2021-12-06T11:09:52.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 4
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-06T11:09:52.000Z
#
# 55
# 1467811401586642946 @ 2021-12-06T11:01:23.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fffmapcount/forests
# Location: N/A
# Datetime: 2021-12-05 00:00:00
#
# 56
# 1467810539652980741 @ 2021-12-06T10:57:57.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-03 00:00:00
#
# 57
# 1467809152600789028 @ 2021-12-06T10:52:27.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 6
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-03 00:00:00
#
# 58
# 1467807940262477825 @ 2021-12-06T10:47:38.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: fffmapcount
# Location: N/A
# Datetime: 2022-01-03 18:48:34.498817
#
# 59
# 1467806531311788040 @ 2021-12-06T10:42:02.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 3
# Organization: fridaysforfuture/fffmapcount/climatestrike
# Location: N/A
# Datetime: 2021-12-06T10:42:02.000Z
#
# 60
# 1467578842399313926 @ 2021-12-05T19:37:16.000Z by 11thHFC
# Number of People: 2
# Organization: N/A
# Location: N/A
# Datetime: 2021-12-02 00:00:00
#
# 61
# 1467450340341653508 @ 2021-12-05T11:06:39.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 25
# Organization: people/fffmapcount
# Location: N/A
# Datetime: 2021-12-03 00:00:00
#
# 62
# 1467448015384371200 @ 2021-12-05T10:57:25.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 400
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-05T10:57:25.000Z
#
# 63
# 1467446392125861890 @ 2021-12-05T10:50:58.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 1
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-05T10:50:58.000Z
#
# 64
# 1466894039224045578 @ 2021-12-03T22:16:07.000Z by @FFF_SAJ ._. Sweden Årsta Janine #UprootTheSystem
# Unable to parse: @Vikrant_sri29 @redmayne_robert @narendramodi @BBCWorld @UN @UNYouthEnvoy @UNEP @byadavbjp @COP26 @M...
#
# 65
# 1466888367480651788 @ 2021-12-03T21:53:34.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @DawnRoseTurner @NayonSorkarBD @GretaThunberg @SwedenAmbBD @SaveFutureBd @Fridays4future @UNEP_Europ...
#
# 66
# 1466887738452496384 @ 2021-12-03T21:51:04.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @ShikhaSeth17 @GretaThunberg @vanessa_vash @KaoHua3 @Fridays4future @FFFIndia @FFFMAPA @parents4futu...
#
# 67
# 1466885984994349057 @ 2021-12-03T21:44:06.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 3
# Organization: fridaysforfuture/fffmapcount/climatestrike
# Location: N/A
# Datetime: 2022-01-04 18:48:37.016817
#
# 68
# 1466437155765563412 @ 2021-12-02T16:00:37.000Z by 💧 Janine Climate #UprootTheSystem
# Unable to parse: @Sdg13Un @ibraheemlass @PTrebaul @inbusiness4good @TomsTweeters @FFF_Aus @KaoHua3 @solhog @RMBlaber5...
#
# 69
# 1466118638562426881 @ 2021-12-01T18:54:57.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: people/fffmapcount/climateaction
# Location: N/A
# Datetime: 2021-11-29 00:00:00
#
# 70
# 1466117777136050177 @ 2021-12-01T18:51:31.000Z by FFF Map count #UprootTheSystem 24th Sept 2021
# Number of People: 4
# Organization: fffmapcount
# Location: N/A
# Datetime: 2021-12-01T18:51:31.000Z
#
# 71
# 1466075160843276298 @ 2021-12-01T16:02:11.000Z by 💧 Janine Climate #UprootTheSystem
# Number of People: 1
# Organization: people/fffmapcount/climateaction
# Location: N/A
# Datetime: 2021-12-01 00:00:00
#
# Was able to parse 57/72 tweets, 15 tweets were not able to be parsed.
# Average Time to Parse: 0.000 seconds

# %%
# 82%
# 0.302s -> x16.7 slower that strict

# %% [markdown]
# # Responding

# %%
import re
import datetime
import torchtext
import dateparser

# %%
def extract_fields(bot_user, tweet): 
    fields = {'num_people':None, 'organization':None, 'location':None, 'datetime':None}
    could_parse = False 

    # Check tweet is not self
    if tweet.author_id==bot_user.id:
        return could_parse, _
    
    # Clean up entities
    url_start_idx = tweet.entities['urls'][0]['start'] if 'urls' in tweet.entities and attempt_clean_url_entities else -1
    
    # Clean text
    text = tweet.text[:url_start_idx].strip().lower()
    text = remove_emoji(text)
    text = re.sub('[,:;(){}##/?@!.\[\]&%$*^\+=|<>`~"\']', ' ', text)
    text = re.sub('  ', ' ', text)
    
    # Tokenize the text (could also split but less reliable)
    tokens = torchtext.data.get_tokenizer("basic_english")(text)    
    
    twiff_idxs = [idx for (idx, token) in enumerate(tokens) if token=='twiff']
    
    for idx in twiff_idxs:
        if idx+1<len(tokens):
            try:
                int(tokens[idx+1])
                tokens = tokens[idx+1:]
                
                # Parse number of people: Can verify
                fields['num_people'] = int(tokens[0])
                del tokens[0]
                
                # Parse datetime
                inferred_datetime = False
                for idx, token in enumerate(tokens): 
                    date = dateparser.parse(token, settings={'STRICT_PARSING':True})
                    if date is not None:  
                        inferred_datetime = True
                        del tokens[idx]
                        break
                if date is not None: fields['datetime'] = date.strftime('%Y-%m-%d')
                        
                # Extract organization
                fields['organization'] = tokens[0]
                del tokens[0]

                # Extract location
                if [idx for (idx, token) in enumerate(tokens) if token=='twiff']:
                    tokens = tokens[:[idx for (idx, token) in enumerate(tokens) if token=='twiff'][0]]
                fields['location'] = ', '.join(tokens)                 
                
                could_parse = True
                
            except ValueError as e:
                None 
    
    return could_parse, fields

# %%
class User:
    def __init__(self, client:Any, identifier:Union[int,str]):
        try:
            int(identifier)
            self.data = client.get_user(id=int(identifier))['data']
        except ValueError as e:
            self.data = client.get_user(username=identifier)['data']
        
        # Variables
        self.id = self.data['id']
        self.name = self.data['name']
        self.username = self.data['username']

# %%
def response(client, bot_user, tweet): 
    # User
    user = User(client, int(tweet.author_id))
    print('Tweet from: {}'.format(user.name))
    
    # Extract Fields
    could_parse, fields = extract_fields(bot_user, tweet)
    print('could_parse={}, fields={}'.format(could_parse, fields))
    
    header = f"Thanks @{user.username} for your climate action 🌏 and using #twiff!"
    who = f"I'm @{bot_user.username}, an automated bot experimenting how to read your tweets for #FFFMapCount!"

    success = f"I've managed to extract some fields from your tweet! \U0001F601"
    failed = f"I wasn't able to extract any fields from your tweet! \U0001F622"

    fields = f"People: {fields['num_people']}\nOrg: {fields['organization']}\nLocation: {fields['location']}\nDate: {fields['datetime']}"

    success_format = f"If any fields are incorrect please reply using the following format: "
    failed_format = f"To have your action registered please reply using the following format: "
    
    twiff_format = f"#twiff [Number of People], [Organization], [Location], [Datetime]"
    example = f"Here is an example of a tweet I picked up recently:\n{0}"
    
    if could_parse:
        text = f"{header} \U0001F601\n\n{fields}\n\n{success_format+twiff_format}"
    else:
        text = f"{header}\n\n{failed}\n\n{failed_format+twiff_format}"
    
    print('Length: {}'.format(len(text)))
    print('\n-----\n{}'.format(text))
    
    return text

# %% [markdown]
# ### Good Tweet

# %%
tweet = list(results.tweets.values())[::-1][0]
bot_user = User(client, 'twiff_bot')

text = response(client, bot_user, tweet)

#client.like(tweet.id)
#client.create_tweet(in_reply_to_tweet_id=tweet.id, text=text) # reply_settings="mentionedUsers",
# Out:
# Tweet from: 💧 Janine Climate #UprootTheSystem
# could_parse=True, fields={'num_people': 1, 'organization': 'fridaysforfuture', 'location': 'netherlands', 'datetime': '2021-12-31'}
# Length: 275
#
# -----
# Thanks @JanineClimate for your climate action 🌏 and using #twiff! 😁
#
# People: 1
# Org: fridaysforfuture
# Location: netherlands
# Date: 2021-12-31
#
# If any fields are incorrect please reply using the following format: #twiff [Number of People], [Organization], [Location], [Datetime]

# %% [markdown]
# ### Bad Tweet

# %%
tweet = list(results.tweets.values())[::-1][12]
bot_user = User(client, 'twiff_bot')

text = response(client, bot_user, tweet)

#client.like(tweet.id)
#client.create_tweet(in_reply_to_tweet_id=tweet.id, text=text)
# Out:
# Tweet from: FFF Map count #UprootTheSystem 24th Sept 2021
# could_parse=False, fields={'num_people': None, 'organization': None, 'location': None, 'datetime': None}
# Length: 258
#
# -----
# Thanks @FFFMapCount for your climate action 🌏 and using #twiff!
#
# I wasn't able to extract any fields from your tweet! 😢
#
# To have your action registered please reply using the following format: #twiff [Number of People], [Organization], [Location], [Datetime]

# %% [markdown]
# ### PSA
#
# Yesterday found X tweets! Managed to parse X correctly! It took me X to process!
#
# We have X users involved in the hashtag!

# %%
# let other people reply -> reply_settings=mentionedUsers -> everyone
# manually set rate limits to 100/day

# %%
# Easy -> 
# Somewhat ->
# Unrelated ->
